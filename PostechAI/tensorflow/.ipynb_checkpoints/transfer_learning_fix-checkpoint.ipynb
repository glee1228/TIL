# %% [markdown]
# ## TensorFlow-Slim image classification model library
#
# git clone https://github.com/tensorflow/models/
#
# **TensorFlow-Slim**은 AlexNet, VGG, ResNet, Inception과 같이 image classification에 사용되는 Deep Learning CNN 모델을 제공하고 있다. CNN 모델 뿐만 아니라 여러 Datasets(ImageNet, CIFAR-10, MNIST 등)도 제공하고 있고 이를 이용한 학습 및 실험 코드도 제공하고 있다. 그리고 각 CNN 모델을 ImageNet 데이터로 학습한 Pre-trained 모델도 제공하여 새로운 Datasets에 대한 Fine-tuning도 가능하게 해준다.

# %%
# %matplotlib inline

import os
import sys
import math
import numpy as np
import tensorflow as tf
from tensorflow.python.tools.inspect_checkpoint import print_tensors_in_checkpoint_file

sys.path.insert(0,'../')
from utils import *
from cifar10_loader import CIFAR10_loader

sys.path.insert(0,'../models/research/slim')
from nets import vgg

slim = tf.contrib.slim

# %% [markdown]
# ### Download CIFAR-10 Dataset
# **CIFAR-10** dataset은 32x32 사이즈의 이미지들로 airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck으로 이루어져있다. 각 클래스 별 6천장씩 구성되어 있으며 이중 50000장이 training에 사용되고 10000장이 test에 사용된다. TF-Slim library에서 제공하는 코드를 이용하여 현재 작업중인 폴더의 하위 폴더에 cifar-10 dataset을 저장한다.
#
# *CIFAR datasets URL*: https://www.cs.toronto.edu/~kriz/cifar.html
#
# *CIFAR-10 download link*: https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz

# %%
data_dir = '../cifar10_data'
data_url = 'http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz'
maybe_download_and_extract(data_url, data_dir, 'cifar-10-batches')

loader = CIFAR10_loader()
class_names = loader.get_class_names()
# Out:
# Extracting Finished

# %%
batch = loader.get_batch(9, (224,224))
fig = plot_images(batch['images'], batch['labels'], class_names)
fig.show()
# Out:
# /home/rom/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# # Parameters
# VGG network는 입력 영상으로 224x224의 image를 받는다. 이번 실습에서는 **CIFAR-10**을 사용하므로 num_classes를 10으로 정의한다. 매 iteration 마다 100개의 images를 학습시키도록 batch_size를 100으로 한다. 총 epoch(학습 횟수)는 5회이고, 500번의 iteration마다 network의 parameters를 저장한다.
#
# learning rate은 초기에 0.001로 정의하고 5 epochs마다 이 값은 1/10로 줄어든다. ImageNet으로 학습된 **VGG-16** network의 parameters는 **vgg_models/vgg_16.ckpt**이다.
#
# #### Exercise 1-1
# 학습 횟수 50회, 초기 learning_rate 0.001, 매 10회 학습 마다 learning_rate은 20%로 감소

# %%
loader.reset() # set iterator as 0

image_size = 224 # input image size of VGG network
num_classes = 10 # CIFAR-10 number of classes
batch_size = 100 # number of images per training iteration

iteration_per_epoch = int(math.floor(loader.get_num_train_examples() / batch_size))
num_epochs = 5 # number of training epoch
save_checkpoint_frequency = 500 # frequency of saving checkpoints
print_frequency = 10

initial_learning_rate = 0.0001 # initial learning rate for optimizer
num_epochs_before_decay = 10
learning_rate_decay_rate = 0.5 # decay rate for learning rate

# %% [markdown]
# ### Download pre-trained model (vgg-16)
#
# https://github.com/tensorflow/models/tree/master/research/slim
#
# TF-Slim github를 보면 ImageNet으로 학습된 Inception, Resnet, VGG 등 다양한 모델들의 checkpoints가 제공된다. 먼저 오늘 실습에 사용될 **VGG-16**의 checkpoint를 다운 받는다.
#
# #### Exercise 1-2
# vgg-19 network로 pre-trained model을 읽어와 학습할 수 있도록 수정

# %%
model_dir = 'vgg_models'
model_url = 'http://download.tensorflow.org/models/vgg_16_2016_08_28.tar.gz'
maybe_download_and_extract(model_url, model_dir, 'vgg_16.ckpt')

checkpoint_path = 'vgg_models/vgg_16.ckpt' # Pre-trained VGG-16 checkpoints

#print_tensors_in_checkpoint_file(file_name=checkpoint_path, tensor_name='', all_tensors=False)
print_tensors_in_checkpoint_file(file_name=checkpoint_path, tensor_name='', all_tensors=True, all_tensor_names=False)
# Out:
# tensor_name:  global_step
# 0
# tensor_name:  vgg_16/conv1/conv1_1/biases
# [ 0.73429835  0.09340367  0.06775674  0.8862966   0.25994542  0.66426694
#  -0.01582893  0.3249065   0.68600726  0.06247932  0.58156496  0.2361475
#   0.69694996  0.19451167  0.4858922   0.44571847  0.5113422   0.208576
#   0.57557714  0.33199573  0.4997983   0.7117759   0.30284074  0.7082712
#   0.04548979  0.7446502   0.29845494  0.48211655  0.81658626  0.62603897
#   0.3768093   2.064037    0.77311045  0.3459577   0.6130958   0.65459156
#   0.39045632  0.50869167  0.2625384   0.23669638  0.07971057  1.1179353
#   0.26129362  0.8697589   0.21543622  0.78007823  0.37015367  0.47993386
#   0.4313978   0.5084194   0.23049663  0.7636527   0.35419866  0.45794216
#   0.4662595   0.09850298  0.3803252   0.66880196  0.4015123   0.90510356
#   0.43166816  1.302014    0.5306885   0.48993504]
# tensor_name:  vgg_16/conv1/conv1_1/weights
# [[[[ 4.80015397e-01 -1.72696680e-01  3.75577137e-02 ... -1.27135560e-01
#     -5.02991639e-02  3.48965675e-02]
#    [ 5.50379455e-01  2.08774377e-02  9.88311544e-02 ... -8.48205537e-02
#     -5.11389151e-02  3.74943428e-02]
#    [ 4.29470569e-01  1.17273867e-01  3.40129584e-02 ... -1.32241577e-01
#     -5.33475243e-02  7.57738389e-03]]
#
#   [[ 4.08547401e-01 -1.70375049e-01 -4.96297423e-03 ... -1.22360572e-01
#     -2.76450396e-01 -3.90796512e-02]
#    [ 4.40074533e-01  4.73412387e-02  5.13819456e-02 ... -9.88498852e-02
#     -2.96195745e-01 -7.04357103e-02]
#    [ 3.73466998e-01  1.62062630e-01  1.70863140e-03 ... -1.48207128e-01
#     -2.35300660e-01 -6.30356818e-02]]
#
#   [[-6.51455522e-02 -1.54351532e-01 -1.38038069e-01 ... -1.29404560e-01
#     -4.62243795e-01 -3.23985279e-01]
#    [-8.13870355e-02  4.18543853e-02 -1.01763301e-01 ... -9.43124294e-02
#     -5.05662560e-01 -3.83694321e-01]
#    [-6.13601133e-02  1.35693997e-01 -1.15694344e-01 ... -1.40158370e-01
#     -3.77666801e-01 -3.00509870e-01]]]
#
#
#  [[[ 3.10477257e-01 -1.87601492e-01  1.66595340e-01 ... -9.88388434e-02
#
# #### Exercise 1-2
# vgg-19 network로 pre-trained model을 읽어와 학습할 수 있도록 수정

# %%
tf.reset_default_graph()

# input placeholders.
images = tf.placeholder(dtype=tf.float32, shape=[batch_size, image_size, image_size, 3],
                           name='images')
labels = tf.placeholder(dtype=tf.int64, shape=[batch_size], name='labels')

# Create the model, use the default arg scope to configure the batch norm parameters.
"""
activation_fn=tf.nn.relu,
weights_regularizer=slim.l2_regularizer(weight_decay),
biases_initializer=tf.zeros_initializer()
padding='SAME'
"""
with slim.arg_scope(vgg.vgg_arg_scope()):
    # 10 classes instead of 1001.
    logits, _ = vgg.vgg_16(images, num_classes=num_classes, is_training=True)
print(logits)

# Before defining remaining layers (softmax, optimizer), selecting the
# variables to be restored
exclude_layers = ['vgg_16/fc8']
#exclude_layers = ['vgg_16/fc8'] # when discaring only the last classification layer
variables_to_restore = slim.get_variables_to_restore(exclude=exclude_layers)
print('===> The list of variables to be restored:')
for i in variables_to_restore: print(i.op.name)
# Out:
# Tensor("vgg_16/fc8/squeezed:0", shape=(100, 10), dtype=float32)
# ===> The list of variables to be restored:
# vgg_16/conv1/conv1_1/weights
# vgg_16/conv1/conv1_1/biases
# vgg_16/conv1/conv1_2/weights
# vgg_16/conv1/conv1_2/biases
# vgg_16/conv2/conv2_1/weights
# vgg_16/conv2/conv2_1/biases
# vgg_16/conv2/conv2_2/weights
# vgg_16/conv2/conv2_2/biases
# vgg_16/conv3/conv3_1/weights
# vgg_16/conv3/conv3_1/biases
# vgg_16/conv3/conv3_2/weights
# vgg_16/conv3/conv3_2/biases
# vgg_16/conv3/conv3_3/weights
# vgg_16/conv3/conv3_3/biases
# vgg_16/conv4/conv4_1/weights
# vgg_16/conv4/conv4_1/biases
# vgg_16/conv4/conv4_2/weights
# vgg_16/conv4/conv4_2/biases
# vgg_16/conv4/conv4_3/weights
# vgg_16/conv4/conv4_3/biases
# vgg_16/conv5/conv5_1/weights
# vgg_16/conv5/conv5_1/biases
# vgg_16/conv5/conv5_2/weights
# vgg_16/conv5/conv5_2/biases
# vgg_16/conv5/conv5_3/weights
# vgg_16/conv5/conv5_3/biases
# vgg_16/fc6/weights
# vgg_16/fc6/biases
# vgg_16/fc7/weights
# vgg_16/fc7/biases

# %% [markdown]
# 학습에 사용할 loss function과 optimizer를 정한다. 해당 실습에서는 cross_entropy와 softmax를 loss function으로 사용하였고, Gradient Descent알고리즘을 optimizer로 사용해 학습시켰다. **tf.contrib.slim.get_variables_to_restore()**을 통해 학습시킬 레이어를 선택할 수 있다.
#
# #### Exercise 1-3
# variable_to_learn을 이용하여 앞 단의 conv layer는 고정시키고 fc layers만 학습되도록 수정
#
# 참조: https://www.tensorflow.org/api_docs/python/tf/contrib/framework/get_variables_to_restore

# %%
# Define the loss function
probabilities = tf.nn.softmax(logits)
loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
    labels=labels, logits=logits, name='cross_entropy_per_example')

print(probabilities)
print(loss)

# select variables to be learned
fix_layers = ['vgg_16/conv1', 'vgg_16/conv2', 'vgg_16/conv3', 'vgg_16/conv4', 'vgg_16/conv5']
variables_to_learn = slim.get_variables_to_restore(exclude=fix_layers)
#variables_to_learn = slim.get_variables_to_restore()

print('\n===> The list of variables to be learned:')
for i in variables_to_learn: print(i.op.name)
# Out:
# Tensor("Softmax:0", shape=(100, 10), dtype=float32)
# Tensor("cross_entropy_per_example/cross_entropy_per_example:0", shape=(100,), dtype=float32)
#
# ===> The list of variables to be learned:
# vgg_16/fc6/weights
# vgg_16/fc6/biases
# vgg_16/fc7/weights
# vgg_16/fc7/biases
# vgg_16/fc8/weights
# vgg_16/fc8/biases

# %%
global_step = tf.Variable(0, trainable=False)
decay_step = int(num_epochs_before_decay * iteration_per_epoch)
    
lr = tf.train.exponential_decay(
    learning_rate = initial_learning_rate,
    global_step = global_step,
    decay_steps = decay_step,
    decay_rate = learning_rate_decay_rate,
    staircase = True)

# Specify the optimizer and create the train op:
optimizer = tf.train.AdamOptimizer(learning_rate=lr)
#optimizer = tf.train.GradientDescentOptimizer(learning_rate=lr)
#train_op = optimizer.minimize(loss, var_list=variables_to_learn, global_step=global_step) # train only target layers (ex: only fc layers)
train_op = optimizer.minimize(loss)

# %% [markdown]
# ### Random initialization and Training from scratch : Fine-tuning VGG-16으로 넘어가서 진행
# 이부분은 수행하지 않고 넘어갑니다.
# **VGG-16** network 모델의 parameters를 Random initialization한 후 **CIFAR-10** dataset으로 학습을 진행한다.

# %%
# Open the session
sess = tf.Session()
sess.run(tf.global_variables_initializer())

conv1_1_weights = tf.get_default_graph().get_tensor_by_name('vgg_16/conv1/conv1_1/weights:0')
fc7_weights = tf.get_default_graph().get_tensor_by_name('vgg_16/fc7/weights:0')

rand_conv1_1 = conv1_1_weights[:,:,:,:].eval(session=sess)
rand_fc7 = fc7_weights[:,:,:,:].eval(session=sess)

print('Weight of conv1_1:')
print(rand_conv1_1[1,1,1,:10])
print('Weight of fc7:')
print(rand_fc7[0,0,0,:10])
# Out:
# Weight of conv1_1:
# [-0.03288876  0.09708223  0.05922115  0.00122584 -0.09965514  0.06916684
#  -0.05432379  0.08485459 -0.07154594  0.03193124]
# Weight of fc7:
# [-0.00714031  0.01519586  0.01633145 -0.01336012 -0.00663505 -0.0034765
#  -0.01792624 -0.02419917 -0.00998451 -0.02212474]

# %%
# Model parameters
save_path = 'cifar10_random-init_checkpoints/cifar10_cnn'
if not os.path.exists('cifar10_random-init_checkpoints'): 
    os.makedirs('cifar10_random-init_checkpoints')
    
# Train the model
saver = tf.train.Saver()
for ie in range(num_epochs):
    for ii in range(iteration_per_epoch):
        # Load a batch data
        batch = loader.get_batch(batch_size, 'train', (224,224))

        # Run the optimizer
        _ = sess.run([train_op], feed_dict={images:batch['images'],
                                            labels:batch['labels']})

        # Print the accuracy and loss of current batch data
        if (ii+1) % print_frequency == 0:
            batch_loss, batch_prob = sess.run([loss, probabilities], 
                                             feed_dict={images:batch['images'],
                                                        labels:batch['labels']})
            pred_labels = np.argmax(batch_prob, axis=1)
            batch_loss = np.mean(batch_loss)
            batch_acc = np.mean(np.equal(pred_labels, batch['labels']))
            print('%d Epoch %d iteration - Loss (%.3f) Accuracy (%.3f)'
                      %(ie+1, ii+1, batch_loss, batch_acc))

        # Save checkpoint
        if (ii+1) % save_checkpoint_frequency == 0:
            saver.save(sess, save_path=save_path, global_step=ie*iteration_per_epoch + ii + 1)
            print('Saved checkpoint %s_%d' % (save_path, ie*iteration_per_epoch + ii + 1))

sess.close()
# Out:
# 1 Epoch 10 iteration - Loss (2.278) Accuracy (0.130)
# 1 Epoch 20 iteration - Loss (2.165) Accuracy (0.190)
# 1 Epoch 30 iteration - Loss (2.269) Accuracy (0.210)
# 1 Epoch 40 iteration - Loss (2.185) Accuracy (0.220)
# 1 Epoch 50 iteration - Loss (1.909) Accuracy (0.250)
# 1 Epoch 60 iteration - Loss (1.877) Accuracy (0.310)
# 1 Epoch 70 iteration - Loss (1.921) Accuracy (0.350)
# 1 Epoch 80 iteration - Loss (1.998) Accuracy (0.280)
# 1 Epoch 90 iteration - Loss (1.875) Accuracy (0.400)
# 1 Epoch 100 iteration - Loss (1.821) Accuracy (0.350)
# 1 Epoch 110 iteration - Loss (1.650) Accuracy (0.280)
# 1 Epoch 120 iteration - Loss (1.773) Accuracy (0.350)
# 1 Epoch 130 iteration - Loss (1.636) Accuracy (0.360)
# 1 Epoch 140 iteration - Loss (1.653) Accuracy (0.320)
# 1 Epoch 150 iteration - Loss (1.780) Accuracy (0.380)
# 1 Epoch 160 iteration - Loss (1.725) Accuracy (0.390)
# 1 Epoch 170 iteration - Loss (1.412) Accuracy (0.530)
# 1 Epoch 180 iteration - Loss (1.573) Accuracy (0.460)
# 1 Epoch 190 iteration - Loss (1.514) Accuracy (0.510)
# 1 Epoch 200 iteration - Loss (1.659) Accuracy (0.370)
# 1 Epoch 210 iteration - Loss (1.469) Accuracy (0.510)
# 1 Epoch 220 iteration - Loss (1.477) Accuracy (0.450)
# 1 Epoch 230 iteration - Loss (1.484) Accuracy (0.490)
# 1 Epoch 240 iteration - Loss (1.489) Accuracy (0.370)
# 1 Epoch 250 iteration - Loss (1.395) Accuracy (0.410)
# 1 Epoch 260 iteration - Loss (1.421) Accuracy (0.440)
# 1 Epoch 270 iteration - Loss (1.424) Accuracy (0.490)
# 1 Epoch 280 iteration - Loss (1.497) Accuracy (0.470)
# 1 Epoch 290 iteration - Loss (1.225) Accuracy (0.530)
# 1 Epoch 300 iteration - Loss (1.253) Accuracy (0.530)
# 1 Epoch 310 iteration - Loss (1.278) Accuracy (0.490)
# 1 Epoch 320 iteration - Loss (1.400) Accuracy (0.600)
# 1 Epoch 330 iteration - Loss (1.427) Accuracy (0.450)
# 1 Epoch 340 iteration - Loss (1.309) Accuracy (0.480)
# 1 Epoch 350 iteration - Loss (1.293) Accuracy (0.520)
# 1 Epoch 360 iteration - Loss (1.290) Accuracy (0.530)
# 1 Epoch 370 iteration - Loss (1.337) Accuracy (0.450)
# 1 Epoch 380 iteration - Loss (1.358) Accuracy (0.540)
# 1 Epoch 390 iteration - Loss (1.172) Accuracy (0.500)
# 1 Epoch 400 iteration - Loss (1.185) Accuracy (0.550)
# 1 Epoch 410 iteration - Loss (1.454) Accuracy (0.450)
# 1 Epoch 420 iteration - Loss (1.181) Accuracy (0.510)
# 1 Epoch 430 iteration - Loss (1.317) Accuracy (0.490)
# 1 Epoch 440 iteration - Loss (1.090) Accuracy (0.620)
# 1 Epoch 450 iteration - Loss (1.200) Accuracy (0.530)
# 1 Epoch 460 iteration - Loss (1.232) Accuracy (0.550)
# 1 Epoch 470 iteration - Loss (1.161) Accuracy (0.570)
# 1 Epoch 480 iteration - Loss (1.140) Accuracy (0.600)
# 1 Epoch 490 iteration - Loss (1.080) Accuracy (0.640)
# 1 Epoch 500 iteration - Loss (1.146) Accuracy (0.640)
# Saved checkpoint cifar10_random-init_checkpoints/cifar10_cnn_500
# 2 Epoch 10 iteration - Loss (0.981) Accuracy (0.680)
# 2 Epoch 20 iteration - Loss (1.068) Accuracy (0.650)
# 2 Epoch 30 iteration - Loss (1.128) Accuracy (0.560)
# 2 Epoch 40 iteration - Loss (1.003) Accuracy (0.600)
# 2 Epoch 50 iteration - Loss (1.150) Accuracy (0.640)
# 2 Epoch 60 iteration - Loss (1.038) Accuracy (0.640)
# 2 Epoch 70 iteration - Loss (1.151) Accuracy (0.570)
# 2 Epoch 80 iteration - Loss (1.153) Accuracy (0.550)
# 2 Epoch 90 iteration - Loss (1.090) Accuracy (0.630)
# 2 Epoch 100 iteration - Loss (1.011) Accuracy (0.610)
# 2 Epoch 110 iteration - Loss (0.947) Accuracy (0.660)
# 2 Epoch 120 iteration - Loss (0.999) Accuracy (0.650)
# 2 Epoch 130 iteration - Loss (0.949) Accuracy (0.710)
# 2 Epoch 140 iteration - Loss (0.903) Accuracy (0.710)
# 2 Epoch 150 iteration - Loss (1.061) Accuracy (0.590)
# 2 Epoch 160 iteration - Loss (1.186) Accuracy (0.560)
# 2 Epoch 170 iteration - Loss (0.955) Accuracy (0.630)
# 2 Epoch 180 iteration - Loss (0.978) Accuracy (0.660)
# 2 Epoch 190 iteration - Loss (0.768) Accuracy (0.730)
# 2 Epoch 200 iteration - Loss (0.913) Accuracy (0.690)
# 2 Epoch 210 iteration - Loss (0.832) Accuracy (0.690)
# 2 Epoch 220 iteration - Loss (0.997) Accuracy (0.630)
# 2 Epoch 230 iteration - Loss (1.126) Accuracy (0.560)
# 2 Epoch 240 iteration - Loss (0.858) Accuracy (0.700)
# 2 Epoch 250 iteration - Loss (0.803) Accuracy (0.750)
# 2 Epoch 260 iteration - Loss (0.902) Accuracy (0.630)
# 2 Epoch 270 iteration - Loss (0.971) Accuracy (0.670)
# 2 Epoch 280 iteration - Loss (0.877) Accuracy (0.720)
# 2 Epoch 290 iteration - Loss (0.587) Accuracy (0.820)
# 2 Epoch 300 iteration - Loss (0.622) Accuracy (0.780)
# 2 Epoch 310 iteration - Loss (0.725) Accuracy (0.750)
# 2 Epoch 320 iteration - Loss (0.868) Accuracy (0.680)
# 2 Epoch 330 iteration - Loss (0.801) Accuracy (0.710)
# 2 Epoch 340 iteration - Loss (0.748) Accuracy (0.670)
# 2 Epoch 350 iteration - Loss (0.817) Accuracy (0.700)
# 2 Epoch 360 iteration - Loss (0.932) Accuracy (0.650)
# 2 Epoch 370 iteration - Loss (0.896) Accuracy (0.720)
# 2 Epoch 380 iteration - Loss (0.905) Accuracy (0.650)
# 2 Epoch 390 iteration - Loss (0.781) Accuracy (0.740)
# 2 Epoch 400 iteration - Loss (0.746) Accuracy (0.730)
# 2 Epoch 410 iteration - Loss (0.883) Accuracy (0.690)
# 2 Epoch 420 iteration - Loss (0.848) Accuracy (0.690)
# 2 Epoch 430 iteration - Loss (0.791) Accuracy (0.750)
# 2 Epoch 440 iteration - Loss (0.764) Accuracy (0.740)
# 2 Epoch 450 iteration - Loss (0.779) Accuracy (0.730)
# 2 Epoch 460 iteration - Loss (0.863) Accuracy (0.670)
# 2 Epoch 470 iteration - Loss (0.746) Accuracy (0.740)
# 2 Epoch 480 iteration - Loss (0.866) Accuracy (0.670)
# 2 Epoch 490 iteration - Loss (0.568) Accuracy (0.820)
# 2 Epoch 500 iteration - Loss (0.688) Accuracy (0.740)
# Saved checkpoint cifar10_random-init_checkpoints/cifar10_cnn_1000
# 3 Epoch 10 iteration - Loss (0.513) Accuracy (0.810)
# 3 Epoch 20 iteration - Loss (0.651) Accuracy (0.830)
# 3 Epoch 30 iteration - Loss (0.791) Accuracy (0.680)
# 3 Epoch 40 iteration - Loss (0.643) Accuracy (0.810)
# 3 Epoch 50 iteration - Loss (0.774) Accuracy (0.750)
# 3 Epoch 60 iteration - Loss (0.535) Accuracy (0.880)
# 3 Epoch 70 iteration - Loss (0.528) Accuracy (0.790)
# 3 Epoch 80 iteration - Loss (0.600) Accuracy (0.800)
# 3 Epoch 90 iteration - Loss (0.696) Accuracy (0.800)
# 3 Epoch 100 iteration - Loss (0.609) Accuracy (0.790)
# 3 Epoch 110 iteration - Loss (0.680) Accuracy (0.710)
# 3 Epoch 120 iteration - Loss (0.634) Accuracy (0.780)
# 3 Epoch 130 iteration - Loss (0.617) Accuracy (0.790)
# 3 Epoch 140 iteration - Loss (0.640) Accuracy (0.800)
# 3 Epoch 150 iteration - Loss (0.654) Accuracy (0.800)
# 3 Epoch 160 iteration - Loss (0.830) Accuracy (0.710)
# 3 Epoch 170 iteration - Loss (0.698) Accuracy (0.740)
# 3 Epoch 180 iteration - Loss (0.596) Accuracy (0.740)
# 3 Epoch 190 iteration - Loss (0.465) Accuracy (0.890)
# 3 Epoch 200 iteration - Loss (0.657) Accuracy (0.740)
# 3 Epoch 210 iteration - Loss (0.530) Accuracy (0.840)
# 3 Epoch 220 iteration - Loss (0.738) Accuracy (0.750)
# 3 Epoch 230 iteration - Loss (0.857) Accuracy (0.730)
# 3 Epoch 240 iteration - Loss (0.513) Accuracy (0.850)
# 3 Epoch 250 iteration - Loss (0.484) Accuracy (0.840)
# 3 Epoch 260 iteration - Loss (0.517) Accuracy (0.820)
# 3 Epoch 270 iteration - Loss (0.503) Accuracy (0.840)
# 3 Epoch 280 iteration - Loss (0.460) Accuracy (0.850)
# 3 Epoch 290 iteration - Loss (0.397) Accuracy (0.880)
# 3 Epoch 300 iteration - Loss (0.299) Accuracy (0.920)
# 3 Epoch 310 iteration - Loss (0.427) Accuracy (0.880)
# 3 Epoch 320 iteration - Loss (0.626) Accuracy (0.770)
# 3 Epoch 330 iteration - Loss (0.548) Accuracy (0.820)
# 3 Epoch 340 iteration - Loss (0.528) Accuracy (0.820)
# 3 Epoch 350 iteration - Loss (0.542) Accuracy (0.800)
# 3 Epoch 360 iteration - Loss (0.629) Accuracy (0.800)
# 3 Epoch 370 iteration - Loss (0.617) Accuracy (0.770)
# 3 Epoch 380 iteration - Loss (0.629) Accuracy (0.710)
# 3 Epoch 390 iteration - Loss (0.475) Accuracy (0.820)
# 3 Epoch 400 iteration - Loss (0.451) Accuracy (0.830)
# 3 Epoch 410 iteration - Loss (0.633) Accuracy (0.810)
# 3 Epoch 420 iteration - Loss (0.439) Accuracy (0.840)
# 3 Epoch 430 iteration - Loss (0.514) Accuracy (0.790)
# 3 Epoch 440 iteration - Loss (0.443) Accuracy (0.820)
# 3 Epoch 450 iteration - Loss (0.525) Accuracy (0.810)
# 3 Epoch 460 iteration - Loss (0.564) Accuracy (0.790)
# 3 Epoch 470 iteration - Loss (0.562) Accuracy (0.840)
# 3 Epoch 480 iteration - Loss (0.465) Accuracy (0.840)
# 3 Epoch 490 iteration - Loss (0.345) Accuracy (0.900)
# 3 Epoch 500 iteration - Loss (0.533) Accuracy (0.800)
# Saved checkpoint cifar10_random-init_checkpoints/cifar10_cnn_1500
# 4 Epoch 10 iteration - Loss (0.351) Accuracy (0.910)
# 4 Epoch 20 iteration - Loss (0.443) Accuracy (0.800)
# 4 Epoch 30 iteration - Loss (0.502) Accuracy (0.830)
# 4 Epoch 40 iteration - Loss (0.439) Accuracy (0.850)
# 4 Epoch 50 iteration - Loss (0.604) Accuracy (0.820)
# 4 Epoch 60 iteration - Loss (0.280) Accuracy (0.930)
# 4 Epoch 70 iteration - Loss (0.291) Accuracy (0.930)
# 4 Epoch 80 iteration - Loss (0.319) Accuracy (0.880)
# 4 Epoch 90 iteration - Loss (0.458) Accuracy (0.860)
# 4 Epoch 100 iteration - Loss (0.414) Accuracy (0.850)
# 4 Epoch 110 iteration - Loss (0.423) Accuracy (0.870)
# 4 Epoch 120 iteration - Loss (0.329) Accuracy (0.880)
# 4 Epoch 130 iteration - Loss (0.275) Accuracy (0.940)
# 4 Epoch 140 iteration - Loss (0.416) Accuracy (0.840)
# 4 Epoch 150 iteration - Loss (0.373) Accuracy (0.900)
# 4 Epoch 160 iteration - Loss (0.358) Accuracy (0.900)
# 4 Epoch 170 iteration - Loss (0.477) Accuracy (0.800)
# 4 Epoch 180 iteration - Loss (0.340) Accuracy (0.890)
# 4 Epoch 190 iteration - Loss (0.310) Accuracy (0.900)
# 4 Epoch 200 iteration - Loss (0.363) Accuracy (0.890)
# 4 Epoch 210 iteration - Loss (0.294) Accuracy (0.890)
# 4 Epoch 220 iteration - Loss (0.517) Accuracy (0.810)
# 4 Epoch 230 iteration - Loss (0.473) Accuracy (0.860)
# 4 Epoch 240 iteration - Loss (0.377) Accuracy (0.860)
# 4 Epoch 250 iteration - Loss (0.341) Accuracy (0.910)
# 4 Epoch 260 iteration - Loss (0.298) Accuracy (0.910)
# 4 Epoch 270 iteration - Loss (0.420) Accuracy (0.840)
# 4 Epoch 280 iteration - Loss (0.259) Accuracy (0.940)
# 4 Epoch 290 iteration - Loss (0.198) Accuracy (0.960)
# 4 Epoch 300 iteration - Loss (0.178) Accuracy (0.960)
# 4 Epoch 310 iteration - Loss (0.289) Accuracy (0.930)
# 4 Epoch 320 iteration - Loss (0.321) Accuracy (0.900)
# 4 Epoch 330 iteration - Loss (0.330) Accuracy (0.890)
# 4 Epoch 340 iteration - Loss (0.351) Accuracy (0.890)
# 4 Epoch 350 iteration - Loss (0.282) Accuracy (0.920)
# 4 Epoch 360 iteration - Loss (0.347) Accuracy (0.870)
# 4 Epoch 370 iteration - Loss (0.380) Accuracy (0.870)
# 4 Epoch 380 iteration - Loss (0.402) Accuracy (0.860)
# 4 Epoch 390 iteration - Loss (0.258) Accuracy (0.920)
# 4 Epoch 400 iteration - Loss (0.306) Accuracy (0.900)
# 4 Epoch 410 iteration - Loss (0.524) Accuracy (0.830)
# 4 Epoch 420 iteration - Loss (0.311) Accuracy (0.900)
# 4 Epoch 430 iteration - Loss (0.423) Accuracy (0.840)
# 4 Epoch 440 iteration - Loss (0.264) Accuracy (0.910)
# 4 Epoch 450 iteration - Loss (0.299) Accuracy (0.900)
# 4 Epoch 460 iteration - Loss (0.369) Accuracy (0.870)
# 4 Epoch 470 iteration - Loss (0.298) Accuracy (0.910)
# 4 Epoch 480 iteration - Loss (0.237) Accuracy (0.930)
# 4 Epoch 490 iteration - Loss (0.243) Accuracy (0.920)
# 4 Epoch 500 iteration - Loss (0.284) Accuracy (0.890)
# Saved checkpoint cifar10_random-init_checkpoints/cifar10_cnn_2000
# 5 Epoch 10 iteration - Loss (0.166) Accuracy (0.940)
# 5 Epoch 20 iteration - Loss (0.295) Accuracy (0.920)
# 5 Epoch 30 iteration - Loss (0.261) Accuracy (0.890)
# 5 Epoch 40 iteration - Loss (0.212) Accuracy (0.940)
# 5 Epoch 50 iteration - Loss (0.403) Accuracy (0.880)
# 5 Epoch 60 iteration - Loss (0.192) Accuracy (0.940)
# 5 Epoch 70 iteration - Loss (0.158) Accuracy (0.940)
# 5 Epoch 80 iteration - Loss (0.234) Accuracy (0.930)
# 5 Epoch 90 iteration - Loss (0.282) Accuracy (0.920)
# 5 Epoch 100 iteration - Loss (0.250) Accuracy (0.940)
# 5 Epoch 110 iteration - Loss (0.190) Accuracy (0.930)
# 5 Epoch 120 iteration - Loss (0.165) Accuracy (0.960)
# 5 Epoch 130 iteration - Loss (0.272) Accuracy (0.910)
# 5 Epoch 140 iteration - Loss (0.287) Accuracy (0.900)
# 5 Epoch 150 iteration - Loss (0.245) Accuracy (0.930)
# 5 Epoch 160 iteration - Loss (0.261) Accuracy (0.910)
# 5 Epoch 170 iteration - Loss (0.188) Accuracy (0.930)
# 5 Epoch 180 iteration - Loss (0.168) Accuracy (0.980)
# 5 Epoch 190 iteration - Loss (0.175) Accuracy (0.960)
# 5 Epoch 200 iteration - Loss (0.238) Accuracy (0.940)
# 5 Epoch 210 iteration - Loss (0.186) Accuracy (0.930)
# 5 Epoch 220 iteration - Loss (0.284) Accuracy (0.880)
# 5 Epoch 230 iteration - Loss (0.228) Accuracy (0.910)
# 5 Epoch 240 iteration - Loss (0.217) Accuracy (0.960)
# 5 Epoch 250 iteration - Loss (0.277) Accuracy (0.920)
# 5 Epoch 260 iteration - Loss (0.154) Accuracy (0.950)
# 5 Epoch 270 iteration - Loss (0.203) Accuracy (0.940)
# 5 Epoch 280 iteration - Loss (0.229) Accuracy (0.930)
# 5 Epoch 290 iteration - Loss (0.161) Accuracy (0.950)
# 5 Epoch 300 iteration - Loss (0.104) Accuracy (0.970)
# 5 Epoch 310 iteration - Loss (0.158) Accuracy (0.970)
# 5 Epoch 320 iteration - Loss (0.179) Accuracy (0.940)
# 5 Epoch 330 iteration - Loss (0.126) Accuracy (0.970)
# 5 Epoch 340 iteration - Loss (0.142) Accuracy (0.970)
# 5 Epoch 350 iteration - Loss (0.247) Accuracy (0.920)
# 5 Epoch 360 iteration - Loss (0.183) Accuracy (0.940)
# 5 Epoch 370 iteration - Loss (0.214) Accuracy (0.920)
# 5 Epoch 380 iteration - Loss (0.184) Accuracy (0.950)
# 5 Epoch 390 iteration - Loss (0.194) Accuracy (0.930)
# 5 Epoch 400 iteration - Loss (0.170) Accuracy (0.950)
# 5 Epoch 410 iteration - Loss (0.183) Accuracy (0.950)
# 5 Epoch 420 iteration - Loss (0.169) Accuracy (0.960)
# 5 Epoch 430 iteration - Loss (0.077) Accuracy (0.970)
# 5 Epoch 440 iteration - Loss (0.130) Accuracy (0.960)
# 5 Epoch 450 iteration - Loss (0.247) Accuracy (0.910)
# 5 Epoch 460 iteration - Loss (0.201) Accuracy (0.920)
# 5 Epoch 470 iteration - Loss (0.184) Accuracy (0.950)
# 5 Epoch 480 iteration - Loss (0.144) Accuracy (0.960)
# 5 Epoch 490 iteration - Loss (0.156) Accuracy (0.950)
# 5 Epoch 500 iteration - Loss (0.127) Accuracy (0.990)
# Saved checkpoint cifar10_random-init_checkpoints/cifar10_cnn_2500

# %% [markdown]
# ### Evaluate Model

# %%
iteration_per_epoch = int(math.floor(loader.get_num_test_examples() / batch_size))
checkpoint_path = tf.train.latest_checkpoint(checkpoint_dir='cifar10_random-init_checkpoints/')
print('Last checkpoint path is %s' % (checkpoint_path))

print(iteration_per_epoch)

# Open the session
sess = tf.Session()
sess.run(tf.global_variables_initializer())

saver = tf.train.Saver()

# Load the checkpoint or initialize the variables
saver.restore(sess, save_path=checkpoint_path)
print('Model is restored from %s' % checkpoint_path)

loader.reset()
num_correct = 0
num_examples = 0
ii = 0

# Evaluate the model
while True:
    # Load a batch data
    batch = loader.get_batch(batch_size, 'test', (224,224))
    if batch['wrapped']: break

    # Compute the correct numbers
    batch_prob = sess.run(probabilities, feed_dict={images:batch['images'],
                                                      labels:batch['labels']})

    pred_labels = np.argmax(batch_prob, axis=1)
    batch_correct_num = np.sum(np.equal(pred_labels, batch['labels']))

    num_correct += batch_correct_num
    num_examples += batch_size
    
    if (ii+1) % 10 == 0:
        print('%d/%d done' % (ii+1, iteration_per_epoch))
    ii += 1
print('Test accuracy: %.2f%%' % (float(num_correct) / float(num_examples) * 100.0))

sess.close()
# Out:
# Last checkpoint path is cifar10_random-init_checkpoints/cifar10_cnn-2500
# 100
# INFO:tensorflow:Restoring parameters from cifar10_random-init_checkpoints/cifar10_cnn-2500
# Model is restored from cifar10_random-init_checkpoints/cifar10_cnn-2500
# 10/100 done
# 20/100 done
# 30/100 done
# 40/100 done
# 50/100 done
# 60/100 done
# 70/100 done
# 80/100 done
# 90/100 done
# 100/100 done
# Test accuracy: 76.13%

# %% [markdown]
# ### Fine-tuning VGG-16
# **vgg_models/vgg_16.ckpt** 파일을 읽어와 위에서 정의한 **VGG-16** network의 parameters을 수정한 후 **CIFAR-10** dataset을 학습시킨다.

# %%
# Create the saver with variables to be restored
restorer = tf.train.Saver(variables_to_restore)

# Open the session
sess = tf.Session()
sess.run(tf.global_variables_initializer())

checkpoint_path='vgg_models/vgg_16.ckpt'
restorer.restore(sess, save_path=checkpoint_path)
    
print('Model is restored from %s' % checkpoint_path)

save_path = 'cifar10_fine-tuning_checkpoints/cifar10_cnn'
if not os.path.exists('cifar10_fine-tuning_checkpoints'): 
    os.makedirs('cifar10_fine-tuning_checkpoints')

# Train the model
saver = tf.train.Saver()
for ie in range(num_epochs):
    for ii in range(iteration_per_epoch):
        # Load a batch data
        batch = loader.get_batch(batch_size, 'train', (224,224))
        
        # Run the optimizer
        _ = sess.run([train_op], feed_dict={images:batch['images'],
                                            labels:batch['labels']})
        '''
        if (num_epochs < 10):
            _ = sess.run([train_op], feed_dict={images:batch['images'],
                                                labels:batch['labels']})
        else:
            _ = sess.run([train_op_all], feed_dict={images:batch['images'],
                                                    labels:batch['labels']})
        '''
        # Print the accuracy and loss of current batch data
        if (ii+1) % print_frequency == 0:
            batch_loss, batch_prob = sess.run([loss, probabilities], 
                                              feed_dict={images:batch['images'],
                                                         labels:batch['labels']})
            pred_labels = np.argmax(batch_prob, axis=1)
            batch_loss = np.mean(batch_loss)
            batch_acc =np.mean(np.equal(pred_labels, batch['labels']))
            print('%d Epoch %d iteration - Loss (%.3f) Accuracy (%.3f)'
                  %(ie+1, ii+1, batch_loss, batch_acc))
            
        # Save checkpoint
        if (ii+1) % save_checkpoint_frequency == 0:
            saver.save(sess, save_path=save_path, global_step=ie*iteration_per_epoch + ii + 1)
            print('Saved checkpoint %s_%d' % (save_path, ie*iteration_per_epoch + ii + 1))
sess.close()
# Out:
# INFO:tensorflow:Restoring parameters from vgg_models/vgg_16.ckpt
# Model is restored from vgg_models/vgg_16.ckpt
# 1 Epoch 10 iteration - Loss (2.036) Accuracy (0.180)
# 1 Epoch 20 iteration - Loss (1.832) Accuracy (0.310)
# 1 Epoch 30 iteration - Loss (1.615) Accuracy (0.440)
# 1 Epoch 40 iteration - Loss (1.424) Accuracy (0.480)
# 1 Epoch 50 iteration - Loss (1.325) Accuracy (0.500)
# 1 Epoch 60 iteration - Loss (1.160) Accuracy (0.580)
# 1 Epoch 70 iteration - Loss (0.939) Accuracy (0.630)
# 1 Epoch 80 iteration - Loss (1.049) Accuracy (0.600)
# 1 Epoch 90 iteration - Loss (0.971) Accuracy (0.670)
# 1 Epoch 100 iteration - Loss (0.951) Accuracy (0.690)
# 1 Epoch 110 iteration - Loss (0.969) Accuracy (0.670)
# 1 Epoch 120 iteration - Loss (0.762) Accuracy (0.720)
# 1 Epoch 130 iteration - Loss (0.809) Accuracy (0.680)
# 1 Epoch 140 iteration - Loss (0.738) Accuracy (0.790)
# 1 Epoch 150 iteration - Loss (0.836) Accuracy (0.730)
# 1 Epoch 160 iteration - Loss (0.816) Accuracy (0.720)
# 1 Epoch 170 iteration - Loss (0.561) Accuracy (0.830)
# 1 Epoch 180 iteration - Loss (0.641) Accuracy (0.780)
# 1 Epoch 190 iteration - Loss (0.493) Accuracy (0.850)
# 1 Epoch 200 iteration - Loss (0.522) Accuracy (0.850)
# 1 Epoch 210 iteration - Loss (0.608) Accuracy (0.780)
# 1 Epoch 220 iteration - Loss (0.656) Accuracy (0.770)
# 1 Epoch 230 iteration - Loss (0.608) Accuracy (0.820)
# 1 Epoch 240 iteration - Loss (0.630) Accuracy (0.810)
# 1 Epoch 250 iteration - Loss (0.390) Accuracy (0.890)
# 1 Epoch 260 iteration - Loss (0.474) Accuracy (0.820)
# 1 Epoch 270 iteration - Loss (0.545) Accuracy (0.790)
# 1 Epoch 280 iteration - Loss (0.330) Accuracy (0.910)
# 1 Epoch 290 iteration - Loss (0.364) Accuracy (0.920)
# 1 Epoch 300 iteration - Loss (0.266) Accuracy (0.930)
# 1 Epoch 310 iteration - Loss (0.347) Accuracy (0.910)
# 1 Epoch 320 iteration - Loss (0.446) Accuracy (0.840)
# 1 Epoch 330 iteration - Loss (0.440) Accuracy (0.820)
# 1 Epoch 340 iteration - Loss (0.473) Accuracy (0.820)
# 1 Epoch 350 iteration - Loss (0.539) Accuracy (0.800)
# 1 Epoch 360 iteration - Loss (0.551) Accuracy (0.780)
# 1 Epoch 370 iteration - Loss (0.581) Accuracy (0.830)
# 1 Epoch 380 iteration - Loss (0.531) Accuracy (0.820)
# 1 Epoch 390 iteration - Loss (0.455) Accuracy (0.880)
# 1 Epoch 400 iteration - Loss (0.312) Accuracy (0.920)
# 1 Epoch 410 iteration - Loss (0.468) Accuracy (0.890)
# 1 Epoch 420 iteration - Loss (0.314) Accuracy (0.910)
# 1 Epoch 430 iteration - Loss (0.574) Accuracy (0.810)
# 1 Epoch 440 iteration - Loss (0.482) Accuracy (0.820)
# 1 Epoch 450 iteration - Loss (0.438) Accuracy (0.860)
# 1 Epoch 460 iteration - Loss (0.361) Accuracy (0.900)
# 1 Epoch 470 iteration - Loss (0.340) Accuracy (0.880)
# 1 Epoch 480 iteration - Loss (0.385) Accuracy (0.890)
# 1 Epoch 490 iteration - Loss (0.356) Accuracy (0.900)
# 1 Epoch 500 iteration - Loss (0.357) Accuracy (0.840)
# Saved checkpoint cifar10_fine-tuning_checkpoints/cifar10_cnn_500
# 2 Epoch 10 iteration - Loss (0.239) Accuracy (0.940)
# 2 Epoch 20 iteration - Loss (0.382) Accuracy (0.870)
# 2 Epoch 30 iteration - Loss (0.324) Accuracy (0.890)
# 2 Epoch 40 iteration - Loss (0.300) Accuracy (0.900)
# 2 Epoch 50 iteration - Loss (0.317) Accuracy (0.890)
# 2 Epoch 60 iteration - Loss (0.155) Accuracy (0.950)
# 2 Epoch 70 iteration - Loss (0.216) Accuracy (0.970)
# 2 Epoch 80 iteration - Loss (0.304) Accuracy (0.910)
# 2 Epoch 90 iteration - Loss (0.435) Accuracy (0.880)
# 2 Epoch 100 iteration - Loss (0.276) Accuracy (0.910)
# 2 Epoch 110 iteration - Loss (0.311) Accuracy (0.890)
# 2 Epoch 120 iteration - Loss (0.287) Accuracy (0.900)
# 2 Epoch 130 iteration - Loss (0.165) Accuracy (0.960)
# 2 Epoch 140 iteration - Loss (0.351) Accuracy (0.890)
# 2 Epoch 150 iteration - Loss (0.331) Accuracy (0.880)
# 2 Epoch 160 iteration - Loss (0.304) Accuracy (0.900)
# 2 Epoch 170 iteration - Loss (0.246) Accuracy (0.950)
# 2 Epoch 180 iteration - Loss (0.258) Accuracy (0.920)
# 2 Epoch 190 iteration - Loss (0.159) Accuracy (0.940)
# 2 Epoch 200 iteration - Loss (0.192) Accuracy (0.940)
# 2 Epoch 210 iteration - Loss (0.302) Accuracy (0.890)
# 2 Epoch 220 iteration - Loss (0.342) Accuracy (0.890)
# 2 Epoch 230 iteration - Loss (0.349) Accuracy (0.860)
# 2 Epoch 240 iteration - Loss (0.235) Accuracy (0.920)
# 2 Epoch 250 iteration - Loss (0.122) Accuracy (0.970)
# 2 Epoch 260 iteration - Loss (0.245) Accuracy (0.900)
# 2 Epoch 270 iteration - Loss (0.160) Accuracy (0.940)
# 2 Epoch 280 iteration - Loss (0.167) Accuracy (0.960)
# 2 Epoch 290 iteration - Loss (0.079) Accuracy (0.980)
# 2 Epoch 300 iteration - Loss (0.172) Accuracy (0.960)
# 2 Epoch 310 iteration - Loss (0.132) Accuracy (0.970)
# 2 Epoch 320 iteration - Loss (0.231) Accuracy (0.910)
# 2 Epoch 330 iteration - Loss (0.159) Accuracy (0.950)
# 2 Epoch 340 iteration - Loss (0.240) Accuracy (0.910)
# 2 Epoch 350 iteration - Loss (0.194) Accuracy (0.950)
# 2 Epoch 360 iteration - Loss (0.124) Accuracy (0.960)
# 2 Epoch 370 iteration - Loss (0.259) Accuracy (0.920)
# 2 Epoch 380 iteration - Loss (0.211) Accuracy (0.960)
# 2 Epoch 390 iteration - Loss (0.109) Accuracy (0.970)
# 2 Epoch 400 iteration - Loss (0.183) Accuracy (0.940)
# 2 Epoch 410 iteration - Loss (0.152) Accuracy (0.970)
# 2 Epoch 420 iteration - Loss (0.131) Accuracy (0.940)
# 2 Epoch 430 iteration - Loss (0.162) Accuracy (0.960)
# 2 Epoch 440 iteration - Loss (0.145) Accuracy (0.950)
# 2 Epoch 450 iteration - Loss (0.226) Accuracy (0.950)
# 2 Epoch 460 iteration - Loss (0.179) Accuracy (0.920)
# 2 Epoch 470 iteration - Loss (0.145) Accuracy (0.950)
# 2 Epoch 480 iteration - Loss (0.200) Accuracy (0.940)
# 2 Epoch 490 iteration - Loss (0.140) Accuracy (0.950)
# 2 Epoch 500 iteration - Loss (0.169) Accuracy (0.910)
# Saved checkpoint cifar10_fine-tuning_checkpoints/cifar10_cnn_1000
# 3 Epoch 10 iteration - Loss (0.104) Accuracy (0.970)
# 3 Epoch 20 iteration - Loss (0.215) Accuracy (0.890)
# 3 Epoch 30 iteration - Loss (0.144) Accuracy (0.960)
# 3 Epoch 40 iteration - Loss (0.174) Accuracy (0.950)
# 3 Epoch 50 iteration - Loss (0.226) Accuracy (0.940)
# 3 Epoch 60 iteration - Loss (0.097) Accuracy (0.970)
# 3 Epoch 70 iteration - Loss (0.087) Accuracy (0.970)
# 3 Epoch 80 iteration - Loss (0.116) Accuracy (0.970)
# 3 Epoch 90 iteration - Loss (0.223) Accuracy (0.940)
# 3 Epoch 100 iteration - Loss (0.163) Accuracy (0.960)
# 3 Epoch 110 iteration - Loss (0.150) Accuracy (0.930)
# 3 Epoch 120 iteration - Loss (0.163) Accuracy (0.940)
# 3 Epoch 130 iteration - Loss (0.102) Accuracy (0.970)
# 3 Epoch 140 iteration - Loss (0.176) Accuracy (0.960)
# 3 Epoch 150 iteration - Loss (0.265) Accuracy (0.910)
# 3 Epoch 160 iteration - Loss (0.161) Accuracy (0.960)
# 3 Epoch 170 iteration - Loss (0.120) Accuracy (0.980)
# 3 Epoch 180 iteration - Loss (0.083) Accuracy (0.980)
# 3 Epoch 190 iteration - Loss (0.100) Accuracy (0.970)
# 3 Epoch 200 iteration - Loss (0.057) Accuracy (1.000)
# 3 Epoch 210 iteration - Loss (0.125) Accuracy (0.970)
# 3 Epoch 220 iteration - Loss (0.150) Accuracy (0.970)
# 3 Epoch 230 iteration - Loss (0.153) Accuracy (0.940)
# 3 Epoch 240 iteration - Loss (0.103) Accuracy (0.960)
# 3 Epoch 250 iteration - Loss (0.068) Accuracy (0.970)
# 3 Epoch 260 iteration - Loss (0.084) Accuracy (0.990)
# 3 Epoch 270 iteration - Loss (0.076) Accuracy (0.990)
# 3 Epoch 280 iteration - Loss (0.069) Accuracy (0.980)
# 3 Epoch 290 iteration - Loss (0.122) Accuracy (0.950)
# 3 Epoch 300 iteration - Loss (0.115) Accuracy (0.960)
# 3 Epoch 310 iteration - Loss (0.049) Accuracy (0.990)
# 3 Epoch 320 iteration - Loss (0.050) Accuracy (0.990)
# 3 Epoch 330 iteration - Loss (0.118) Accuracy (0.980)
# 3 Epoch 340 iteration - Loss (0.072) Accuracy (0.990)
# 3 Epoch 350 iteration - Loss (0.121) Accuracy (0.970)
# 3 Epoch 360 iteration - Loss (0.067) Accuracy (0.980)
# 3 Epoch 370 iteration - Loss (0.107) Accuracy (0.970)
# 3 Epoch 380 iteration - Loss (0.131) Accuracy (0.970)
# 3 Epoch 390 iteration - Loss (0.163) Accuracy (0.940)
# 3 Epoch 400 iteration - Loss (0.079) Accuracy (0.970)
# 3 Epoch 410 iteration - Loss (0.106) Accuracy (0.960)
# 3 Epoch 420 iteration - Loss (0.066) Accuracy (0.990)
# 3 Epoch 430 iteration - Loss (0.111) Accuracy (0.990)
# 3 Epoch 440 iteration - Loss (0.098) Accuracy (0.960)
# 3 Epoch 450 iteration - Loss (0.061) Accuracy (0.980)
# 3 Epoch 460 iteration - Loss (0.079) Accuracy (0.980)
# 3 Epoch 470 iteration - Loss (0.101) Accuracy (0.970)
# 3 Epoch 480 iteration - Loss (0.097) Accuracy (0.970)
# 3 Epoch 490 iteration - Loss (0.106) Accuracy (0.980)
# 3 Epoch 500 iteration - Loss (0.053) Accuracy (0.990)
# Saved checkpoint cifar10_fine-tuning_checkpoints/cifar10_cnn_1500
# 4 Epoch 10 iteration - Loss (0.069) Accuracy (0.980)
# 4 Epoch 20 iteration - Loss (0.077) Accuracy (0.970)
# 4 Epoch 30 iteration - Loss (0.081) Accuracy (0.980)
# 4 Epoch 40 iteration - Loss (0.096) Accuracy (0.970)
# 4 Epoch 50 iteration - Loss (0.093) Accuracy (0.970)
# 4 Epoch 60 iteration - Loss (0.023) Accuracy (1.000)
# 4 Epoch 70 iteration - Loss (0.051) Accuracy (1.000)
# 4 Epoch 80 iteration - Loss (0.081) Accuracy (0.980)
# 4 Epoch 90 iteration - Loss (0.116) Accuracy (0.970)
# 4 Epoch 100 iteration - Loss (0.063) Accuracy (1.000)
# 4 Epoch 110 iteration - Loss (0.051) Accuracy (0.990)
# 4 Epoch 120 iteration - Loss (0.073) Accuracy (1.000)
# 4 Epoch 130 iteration - Loss (0.021) Accuracy (1.000)
# 4 Epoch 140 iteration - Loss (0.090) Accuracy (0.970)
# 4 Epoch 150 iteration - Loss (0.102) Accuracy (0.960)
# 4 Epoch 160 iteration - Loss (0.070) Accuracy (0.990)
# 4 Epoch 170 iteration - Loss (0.046) Accuracy (1.000)
# 4 Epoch 180 iteration - Loss (0.045) Accuracy (0.990)
# 4 Epoch 190 iteration - Loss (0.035) Accuracy (1.000)
# 4 Epoch 200 iteration - Loss (0.023) Accuracy (0.990)
# 4 Epoch 210 iteration - Loss (0.029) Accuracy (1.000)
# 4 Epoch 220 iteration - Loss (0.050) Accuracy (0.990)
# 4 Epoch 230 iteration - Loss (0.081) Accuracy (0.960)
# 4 Epoch 240 iteration - Loss (0.067) Accuracy (0.970)
# 4 Epoch 250 iteration - Loss (0.091) Accuracy (0.970)
# 4 Epoch 260 iteration - Loss (0.036) Accuracy (0.990)
# 4 Epoch 270 iteration - Loss (0.038) Accuracy (0.990)
# 4 Epoch 280 iteration - Loss (0.036) Accuracy (1.000)
# 4 Epoch 290 iteration - Loss (0.086) Accuracy (0.970)
# 4 Epoch 300 iteration - Loss (0.083) Accuracy (0.980)
# 4 Epoch 310 iteration - Loss (0.094) Accuracy (0.990)
# 4 Epoch 320 iteration - Loss (0.048) Accuracy (1.000)
# 4 Epoch 330 iteration - Loss (0.041) Accuracy (1.000)
# 4 Epoch 340 iteration - Loss (0.085) Accuracy (0.980)
# 4 Epoch 350 iteration - Loss (0.058) Accuracy (0.980)
# 4 Epoch 360 iteration - Loss (0.035) Accuracy (1.000)
# 4 Epoch 370 iteration - Loss (0.060) Accuracy (0.980)
# 4 Epoch 380 iteration - Loss (0.073) Accuracy (0.980)
# 4 Epoch 390 iteration - Loss (0.067) Accuracy (0.990)
# 4 Epoch 400 iteration - Loss (0.020) Accuracy (1.000)
# 4 Epoch 410 iteration - Loss (0.110) Accuracy (0.970)
# 4 Epoch 420 iteration - Loss (0.054) Accuracy (1.000)
# 4 Epoch 430 iteration - Loss (0.024) Accuracy (1.000)
# 4 Epoch 440 iteration - Loss (0.044) Accuracy (0.990)
# 4 Epoch 450 iteration - Loss (0.067) Accuracy (0.960)
# 4 Epoch 460 iteration - Loss (0.048) Accuracy (0.990)
# 4 Epoch 470 iteration - Loss (0.031) Accuracy (1.000)
# 4 Epoch 480 iteration - Loss (0.022) Accuracy (1.000)
# 4 Epoch 490 iteration - Loss (0.034) Accuracy (1.000)
# 4 Epoch 500 iteration - Loss (0.046) Accuracy (0.990)
# Saved checkpoint cifar10_fine-tuning_checkpoints/cifar10_cnn_2000
# 5 Epoch 10 iteration - Loss (0.016) Accuracy (1.000)
# 5 Epoch 20 iteration - Loss (0.039) Accuracy (0.990)
# 5 Epoch 30 iteration - Loss (0.054) Accuracy (0.980)
# 5 Epoch 40 iteration - Loss (0.041) Accuracy (0.990)
# 5 Epoch 50 iteration - Loss (0.032) Accuracy (0.990)
# 5 Epoch 60 iteration - Loss (0.014) Accuracy (1.000)
# 5 Epoch 70 iteration - Loss (0.020) Accuracy (0.990)
# 5 Epoch 80 iteration - Loss (0.011) Accuracy (1.000)
# 5 Epoch 90 iteration - Loss (0.045) Accuracy (0.980)
# 5 Epoch 100 iteration - Loss (0.026) Accuracy (1.000)
# 5 Epoch 110 iteration - Loss (0.029) Accuracy (1.000)
# 5 Epoch 120 iteration - Loss (0.061) Accuracy (0.990)
# 5 Epoch 130 iteration - Loss (0.020) Accuracy (1.000)
# 5 Epoch 140 iteration - Loss (0.028) Accuracy (1.000)
# 5 Epoch 150 iteration - Loss (0.048) Accuracy (0.990)
# 5 Epoch 160 iteration - Loss (0.041) Accuracy (0.990)
# 5 Epoch 170 iteration - Loss (0.020) Accuracy (1.000)
# 5 Epoch 180 iteration - Loss (0.009) Accuracy (1.000)
# 5 Epoch 190 iteration - Loss (0.011) Accuracy (1.000)
# 5 Epoch 200 iteration - Loss (0.078) Accuracy (0.980)
# 5 Epoch 210 iteration - Loss (0.046) Accuracy (0.990)
# 5 Epoch 220 iteration - Loss (0.032) Accuracy (0.990)
# 5 Epoch 230 iteration - Loss (0.085) Accuracy (0.970)
# 5 Epoch 240 iteration - Loss (0.047) Accuracy (0.990)
# 5 Epoch 250 iteration - Loss (0.010) Accuracy (1.000)
# 5 Epoch 260 iteration - Loss (0.034) Accuracy (1.000)
# 5 Epoch 270 iteration - Loss (0.024) Accuracy (1.000)
# 5 Epoch 280 iteration - Loss (0.020) Accuracy (1.000)
# 5 Epoch 290 iteration - Loss (0.016) Accuracy (1.000)
# 5 Epoch 300 iteration - Loss (0.032) Accuracy (0.980)
# 5 Epoch 310 iteration - Loss (0.029) Accuracy (1.000)
# 5 Epoch 320 iteration - Loss (0.042) Accuracy (0.990)
# 5 Epoch 330 iteration - Loss (0.024) Accuracy (1.000)
# 5 Epoch 340 iteration - Loss (0.097) Accuracy (0.960)
# 5 Epoch 350 iteration - Loss (0.033) Accuracy (0.990)
# 5 Epoch 360 iteration - Loss (0.020) Accuracy (1.000)
# 5 Epoch 370 iteration - Loss (0.074) Accuracy (0.990)
# 5 Epoch 380 iteration - Loss (0.026) Accuracy (1.000)
# 5 Epoch 390 iteration - Loss (0.061) Accuracy (0.980)
# 5 Epoch 400 iteration - Loss (0.025) Accuracy (1.000)
# 5 Epoch 410 iteration - Loss (0.047) Accuracy (0.990)
# 5 Epoch 420 iteration - Loss (0.023) Accuracy (1.000)
# 5 Epoch 430 iteration - Loss (0.031) Accuracy (0.990)
# 5 Epoch 440 iteration - Loss (0.033) Accuracy (0.990)
# 5 Epoch 450 iteration - Loss (0.024) Accuracy (1.000)
# 5 Epoch 460 iteration - Loss (0.014) Accuracy (1.000)
# 5 Epoch 470 iteration - Loss (0.051) Accuracy (0.980)
# 5 Epoch 480 iteration - Loss (0.025) Accuracy (0.990)
# 5 Epoch 490 iteration - Loss (0.015) Accuracy (1.000)
# 5 Epoch 500 iteration - Loss (0.008) Accuracy (1.000)
# Saved checkpoint cifar10_fine-tuning_checkpoints/cifar10_cnn_2500

# %% [markdown]
# ### Evaluate the model

# %%
iteration_per_epoch = int(math.floor(loader.get_num_test_examples() / batch_size))
checkpoint_path = tf.train.latest_checkpoint(checkpoint_dir='cifar10_fine-tuning_checkpoints/')
print('Last checkpoint path is %s' % (checkpoint_path))

# Open the session
sess = tf.Session()

saver = tf.train.Saver()

# Load the checkpoint or initialize the variables
saver.restore(sess, save_path=checkpoint_path)
print('Model is restored from %s' % checkpoint_path)

loader.reset()
num_correct = 0
num_examples = 0
ii=0

# Evaluate the model
while True:
    # Load a batch data
    batch = loader.get_batch(batch_size, 'test', (224,224))
    if batch['wrapped']: break

    # Compute the correct numbers
    batch_prob = sess.run(probabilities, feed_dict={images:batch['images'],
                                                      labels:batch['labels']})

    pred_labels = np.argmax(batch_prob, axis=1)
    batch_correct_num = np.sum(np.equal(pred_labels, batch['labels']))
    
    num_correct += batch_correct_num
    num_examples += batch_size
    
    #print('Number of correct data: %d' % batch_correct_num)
    #print('Number of total data: %d' % num_examples)
    
    if (ii+1) % 10 == 0:
        print('%d/%d done' % (ii+1, iteration_per_epoch))
    ii += 1
    
print('Test accuracy: %.2f%%' % (float(num_correct) / float(num_examples) * 100.0))

sess.close()
# Out:
# Last checkpoint path is cifar10_fine-tuning_checkpoints/cifar10_cnn-2500
# INFO:tensorflow:Restoring parameters from cifar10_fine-tuning_checkpoints/cifar10_cnn-2500
# Model is restored from cifar10_fine-tuning_checkpoints/cifar10_cnn-2500
# 10/100 done
# 20/100 done
# 30/100 done
# 40/100 done
# 50/100 done
# 60/100 done
# 70/100 done
# 80/100 done
# 90/100 done
# 100/100 done
# Test accuracy: 88.69%

# %% [markdown]
# ### Exercise 1
# 위 코드를 다음과 같은 내용이 될 수 있도록 수정하도록 한다.
# 1. 학습 횟수 50회, 초기 learning_rate 0.001, 매 10회 학습 마다 learning_rate은 20%로 감소
# 2. vgg-19 network로 pre-trained model을 읽어와 학습할 수 있도록 수정
# 3. variable_to_learn을 이용하여 앞 단의 conv layer는 고정시키고 fc layers만 학습되도록 수정
#
# ### Exercise 2
# 아래 코드는 **/models/research/slim/nets/vgg.py**에 정의된 vgg-16, vgg-19 네트워크의 정의이다. vgg network의 구조와 아래 코드를 참고하여 vgg-postech 네트워크를 구현해보록 한다.
#
# ![VGG-network](../vgg-network.jpg)

# %%
def vgg_arg_scope(weight_decay=0.0005):
  """Defines the VGG arg scope.

  Args:
    weight_decay: The l2 regularization coefficient.

  Returns:
    An arg_scope.
  """
  with slim.arg_scope([slim.conv2d, slim.fully_connected],
                      activation_fn=tf.nn.relu,
                      weights_regularizer=slim.l2_regularizer(weight_decay),
                      biases_initializer=tf.zeros_initializer()):
    with slim.arg_scope([slim.conv2d], padding='SAME') as arg_sc:
      return arg_sc

def vgg_16(inputs,
           num_classes=1000,
           is_training=True,
           dropout_keep_prob=0.5,
           spatial_squeeze=True,
           scope='vgg_16',
           fc_conv_padding='VALID'):
    with tf.variable_scope(scope, 'vgg_16', [inputs]) as sc:
        end_points_collection = sc.name + '_end_points'
        # Collect outputs for conv2d, fully_connected and max_pool2d.
        with slim.arg_scope([slim.conv2d, slim.fully_connected, slim.max_pool2d],
                            outputs_collections=end_points_collection):
            net = slim.repeat(inputs, 2, slim.conv2d, 64, [3, 3], scope='conv1')
            net = slim.max_pool2d(net, [2, 2], scope='pool1')
            net = slim.repeat(net, 2, slim.conv2d, 128, [3, 3], scope='conv2')
            net = slim.max_pool2d(net, [2, 2], scope='pool2')
            net = slim.repeat(net, 3, slim.conv2d, 256, [3, 3], scope='conv3')
            net = slim.max_pool2d(net, [2, 2], scope='pool3')
            net = slim.repeat(net, 3, slim.conv2d, 512, [3, 3], scope='conv4')
            net = slim.max_pool2d(net, [2, 2], scope='pool4')
            net = slim.repeat(net, 3, slim.conv2d, 512, [3, 3], scope='conv5')
            net = slim.max_pool2d(net, [2, 2], scope='pool5')
            # Use conv2d instead of fully_connected layers.
            net = slim.conv2d(net, 4096, [7, 7], padding=fc_conv_padding, scope='fc6')
            net = slim.dropout(net, dropout_keep_prob, is_training=is_training,
                             scope='dropout6')
            net = slim.conv2d(net, 4096, [1, 1], scope='fc7')
            net = slim.dropout(net, dropout_keep_prob, is_training=is_training,
                             scope='dropout7')
            net = slim.conv2d(net, num_classes, [1, 1],
                            activation_fn=None,
                            normalizer_fn=None,
                            scope='fc8')
            
            # Convert end_points_collection into a end_point dict.
            end_points = slim.utils.convert_collection_to_dict(end_points_collection)
            if spatial_squeeze:
                net = tf.squeeze(net, [1, 2], name='fc8/squeezed')
                end_points[sc.name + '/fc8'] = net
            return net, end_points

def vgg_19(inputs,
           num_classes=1000,
           is_training=True,
           dropout_keep_prob=0.5,
           spatial_squeeze=True,
           scope='vgg_19',
           fc_conv_padding='VALID'):

    with tf.variable_scope(scope, 'vgg_19', [inputs]) as sc:
        end_points_collection = sc.name + '_end_points'
        # Collect outputs for conv2d, fully_connected and max_pool2d.
        with slim.arg_scope([slim.conv2d, slim.fully_connected, slim.max_pool2d],
                            outputs_collections=end_points_collection):
            net = slim.repeat(inputs, 2, slim.conv2d, 64, [3, 3], scope='conv1')
            net = slim.max_pool2d(net, [2, 2], scope='pool1')
            net = slim.repeat(net, 2, slim.conv2d, 128, [3, 3], scope='conv2')
            net = slim.max_pool2d(net, [2, 2], scope='pool2')
            net = slim.repeat(net, 4, slim.conv2d, 256, [3, 3], scope='conv3')
            net = slim.max_pool2d(net, [2, 2], scope='pool3')
            net = slim.repeat(net, 4, slim.conv2d, 512, [3, 3], scope='conv4')
            net = slim.max_pool2d(net, [2, 2], scope='pool4')
            net = slim.repeat(net, 4, slim.conv2d, 512, [3, 3], scope='conv5')
            net = slim.max_pool2d(net, [2, 2], scope='pool5')
            # Use conv2d instead of fully_connected layers.
            net = slim.conv2d(net, 4096, [7, 7], padding=fc_conv_padding, scope='fc6')
            net = slim.dropout(net, dropout_keep_prob, is_training=is_training,
                               scope='dropout6')
            net = slim.conv2d(net, 4096, [1, 1], scope='fc7')
            net = slim.dropout(net, dropout_keep_prob, is_training=is_training,
                               scope='dropout7')
            net = slim.conv2d(net, num_classes, [1, 1],
                              activation_fn=None,
                              normalizer_fn=None,
                              scope='fc8')
            
            # Convert end_points_collection into a end_point dict.
            end_points = slim.utils.convert_collection_to_dict(end_points_collection)
            if spatial_squeeze:
                net = tf.squeeze(net, [1, 2], name='fc8/squeezed')
                end_points[sc.name + '/fc8'] = net
            return net, end_points
        
        
#TODO: implement VGG-POSTECH network
def vgg_postech(inputs,
           num_classes=1000,
           is_training=True,
           dropout_keep_prob=0.5,
           spatial_squeeze=True,
           scope='vgg_postech',
           fc_conv_padding='VALID'):
    with tf.variable_scope(scope, 'vgg_postech', [inputs]) as sc:
        end_points_collection = sc.name + '_end_points'
        #TODO : implement VGG-postech
        
        
        # Convert end_points_collection into a end_point dict.
        end_points = slim.utils.convert_collection_to_dict(end_points_collection)
        if spatial_squeeze:
            net = tf.squeeze(net, [1, 2], name='fc8/squeezed')
            end_points[sc.name + '/fc8'] = net
        return net, end_points
