# %% [markdown]
# # pandas
# pandas: 효과적인 데이터 분석을 위한 고수준의 자료구조와 데이터 분석 도구를 제공하는 라이브러리
# - pandas Series: 1차원 데이터를 다루는 데 효과적인 자료구조
# - pandas DataFrame: 행과 열로 구성된 2차원의 데이터를 다루는 데 효과적인 자료구조
#
# 참고1) 파이썬으로 배우는 트레이딩 알고리즘 (https://wikidocs.net/4367) <br>
# 참고2) Python for Data Analysis <br>
# 참고3) pandas documentation (https://pandas.pydata.org/pandas-docs/stable/dsintro.html)

# %%
import pandas as pd

# %% [markdown]
# # Series
# - 어떤 면에서는 파이썬의 리스트와 비슷하고 어떤 면에서는 딕셔너리와 닮은 자료구조
# - 일차원 배열과 달리 값뿐만 아니라 각 값에 연결된 인덱스 값도 저장<br>
#
# <font size = 4.7><center>< __Structure of Series__ ></center></font>
# <img src="https://wikidocs.net/images/page/4364/r13.02.png" alt="Drawing" style="width: 300px;"/>

# %%
from pandas import Series

# %%
kakao = Series([92600, 92400, 92100, 94300, 92300])
kakao
# Out:
# 0    92600
# 1    92400
# 2    92100
# 3    94300
# 4    92300
# dtype: int64

# %%
kakao2 = Series([92600, 92400, 92100, 94300, 92300], 
                index=['2016-02-19', '2016-02-18', '2016-02-17', '2016-02-16', '2016-02-15'])
kakao2
# Out:
# 2016-02-19    92600
# 2016-02-18    92400
# 2016-02-17    92100
# 2016-02-16    94300
# 2016-02-15    92300
# dtype: int64

# %% [markdown]
# # DataFrame
# - pandas의 주요 자료 구조
# - 행과 열로 구성된 2차원 형태의 자료구조 (일반적인 엑셀 문서의 형태)
# - Series 객체를 담는 사전이라고 생각할 수 있음<br><br>
#
# <font size = 4.7><center>< __Structure of DataFrame__ ></center></font>
# <img src="https://wikidocs.net/images/page/4367/r13.10.png" alt="Drawing" style="width: 550px;"/>
# <br>
# <br>
# <font size = 4.7><center>< __DataFrame as dictionary of Series__ ></center></font>
# <img src="https://wikidocs.net/images/page/4367/r13.11.png" alt="Drawing" style="width: 650px;"/>

# %%
from pandas import DataFrame

# %%
raw_data = {'col0': [1, 2, 3, 4],
            'col1': [10, 20, 30, 40],
            'col2': [100, 200, 300, 400]}

data = DataFrame(raw_data)
data
# Out:
#    col0  col1  col2
# 0     1    10   100
# 1     2    20   200
# 2     3    30   300
# 3     4    40   400

# %%
daeshin = {'open':  [11650, 11100, 11200, 11100, 11000],
           'high':  [12100, 11800, 11200, 11100, 11150],
           'low' :  [11600, 11050, 10900, 10950, 10900],
           'close': [11900, 11600, 11000, 11100, 11050]}

date = ['16.02.29', '16.02.26', '16.02.25', '16.02.24', '16.02.23']

daeshin_day = DataFrame(daeshin, columns=['open', 'high', 'low', 'close'], index=date)
daeshin_day
# Out:
#            open   high    low  close
# 16.02.29  11650  12100  11600  11900
# 16.02.26  11100  11800  11050  11600
# 16.02.25  11200  11200  10900  11000
# 16.02.24  11100  11100  10950  11100
# 16.02.23  11000  11150  10900  11050

# %% [markdown]
# # Getting Started with pandas

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ## Creating Series & DataFrame
# #### Series
# - from ndarray
# - from dict
# - from scalar value
# <br>
#
# #### DataFrame
# - from dict of Series or dicts
# - from dict of ndarrays / lists
# - from structured or record array
# - from a list of dicts
# - from a dict of tuples
# - from a Series
#
# *참고: pandas documentation (https://pandas.pydata.org/pandas-docs/stable/dsintro.html)

# %% [markdown]
# ## Load Data
# - CSV
# - Excel
# - Database
# - URL
#
# *참고: http://www.gregreda.com/2013/10/26/intro-to-pandas-data-structures/

# %% [markdown]
# ## Read csv
# - csv 파일 읽어오기

# %% [markdown]
# tips data description
# - customer_id: customer id
# - total_bill: total bill (cost of the meal), including tax, in US dollars
# - tip: tip (gratuity) in US dollars
# - sex: sex of person paying for the meal (male, Female)
# - smoker: somker in party? (No, Yes)
# - day: Thur, Fri, Sat, Sun
# - time: Lunch, Dinner
# - size: size of the party

# %%
# read_csv 함수
tips = pd.read_csv('tips.csv')
tips
# Out:
#      customer_id  total_bill   tip     sex smoker       day    time  size
# 0              1       16.99  1.01  Female     No       Sun  Dinner   2.0
# 1              2       10.34  1.66    Male     No    Sunday  Dinner   3.0
# 2              3       21.01  3.50    Male     No       Sun  Dinner   3.0
# 3              4       23.68  3.31    Male     No       Sun  Dinner   2.0
# 4              5       24.59  3.61  Female     No       Sun  Dinner   4.0
# 5              6       25.29  4.71    Male     No       Sun  Dinner   4.0
# 6              7        8.77  2.00    Male     No       Sun  Dinner   2.0
# 7              8       26.88  3.12    Male     No    Sunday  Dinner   4.0
# 8              9       15.04  1.96    Male     No       Sun  Dinner   2.0
# 9             10       14.78  3.23    Male     No       Sun  Dinner   2.0
# 10            11       10.27  1.71    Male     No       Sun  Dinner   2.0
# 11            12       35.26  5.00  Female     No    Sunday  Dinner   4.0
# 12            13       15.42  1.57    Male     No       Sun  Dinner   2.0
# 13            14       18.43  3.00    Male     No       Sun  Dinner   4.0
# 14            15       14.83  3.02  Female     No    Sunday  Dinner   2.0
# 15            16       21.58  3.92    Male     No       Sun  Dinner   2.0
# 16            17       10.33  1.67  Female     No    Sunday  Dinner   3.0
# 17            18       16.29  3.71    Male     No    Sunday  Dinner   3.0
# 18            19       16.97  3.50  Female     No       Sun  Dinner   3.0
# 19            20       20.65  3.35    Male     No  Saturday  Dinner   3.0
# 20            21       17.92  4.08    Male     No       Sat  Dinner   2.0
# 21            22       20.29  2.75  Female     No       Sat  Dinner   2.0
# 22            23       15.77  2.23  Female     No       Sat  Dinner   2.0
# 23            24       39.42  7.58    Male     No       Sat  Dinner   4.0
# 24            25       19.82  3.18    Male     No       Sat  Dinner   2.0
# 25            26       17.81  2.34    Male     No       Sat  Dinner   4.0
# 26            27       13.37  2.00    Male     No       Sat  Dinner   2.0
# 27            28       12.69  2.00    Male     No  saturday  Dinner   2.0
# 28            29       21.70  4.30    Male     No       Sat  Dinner   2.0
# 29            30       19.65  3.00  Female     No       Sat  Dinner   2.0
# ..           ...         ...   ...     ...    ...       ...     ...   ...
# 221          219       28.17  6.50  Female    Yes       Sat  Dinner   3.0
# 222          220       12.90  1.10  Female    Yes       Sat  Dinner   2.0
# 223          221       28.15  3.00    Male    Yes       Sat  Dinner   5.0
# 224          222       11.59  1.50    Male    Yes       Sat  Dinner   2.0
# 225          223        7.74  1.44    Male    Yes       Sat  Dinner   2.0
# 226          224       30.14  3.09  Female    Yes       Sat  Dinner   4.0
# 227          225       12.16  2.20    Male    Yes       Fri   Lunch   2.0
# 228          226       13.42  3.48  Female    Yes       Fri   Lunch   2.0
# 229          227        8.58  1.92    Male    Yes    Friday   Lunch   1.0
# 230          228       15.98  3.00  Female     No    Friday   Lunch   3.0
# 231          229       13.42  1.58    Male    Yes       Fri   Lunch   2.0
# 232          230       16.27  2.50  Female    Yes       Fri   Lunch   2.0
# 233          231       10.09  2.00  Female    Yes       Fri   Lunch   2.0
# 234          232       20.45  3.00    Male     No       Sat  Dinner   4.0
# 235          233       13.28  2.72    Male     No       Sat  Dinner   2.0
# 236          234       22.12  2.88  Female    Yes       Sat  Dinner   2.0
# 237          235       24.01  2.00    Male    Yes       Sat  Dinner   4.0
# 238          236       15.69  3.00    Male    Yes       Sat  Dinner   3.0
# 239          237       11.61  3.39    Male     No       Sat  Dinner   2.0
# 240          238       10.77  1.47    Male     No       Sat  Dinner   2.0
# 241          239       15.53  3.00    Male    Yes       Sat  Dinner   2.0
# 242          240       10.07  1.25    Male     No       Sat  Dinner   2.0
# 243          241       12.60  1.00    Male    Yes       Sat  Dinner   2.0
# 244          242       32.83  1.17    Male    Yes       Sat  Dinner   2.0
# 245          243       35.83  4.67  Female     No       Sat  Dinner   3.0
# 246          244       29.03  5.92    Male     No       Sat  Dinner   3.0
# 247          245       27.18  2.00  Female    Yes       Sat  Dinner   2.0
# 248          246       22.67  2.00    Male    Yes       Sat  Dinner   2.0
# 249          247       17.82  1.75    Male     No       Sat  Dinner   2.0
# 250          248       18.78  3.00  Female     No      Thur  Dinner   2.0
#
# [251 rows x 8 columns]

# %% [markdown]
# ## Looking through data

# %% [markdown]
# 전체적으로 데이터 훑어보기

# %%
tips.describe()
# Out:
#        customer_id  total_bill         tip        size
# count   251.000000  251.000000  248.000000  250.000000
# mean    124.191235   19.987689    2.998347    2.580000
# std      71.523558    9.046846    1.382070    0.950375
# min       1.000000    3.070000    1.000000    1.000000
# 25%      62.500000   13.405000    2.000000    2.000000
# 50%     124.000000   17.820000    2.855000    2.000000
# 75%     185.500000   24.535000    3.562500    3.000000
# max     248.000000   50.810000   10.000000    6.000000

# %%
tips.head()
# Out:
#    customer_id  total_bill   tip     sex smoker     day    time  size
# 0            1       16.99  1.01  Female     No     Sun  Dinner   2.0
# 1            2       10.34  1.66    Male     No  Sunday  Dinner   3.0
# 2            3       21.01  3.50    Male     No     Sun  Dinner   3.0
# 3            4       23.68  3.31    Male     No     Sun  Dinner   2.0
# 4            5       24.59  3.61  Female     No     Sun  Dinner   4.0

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 8 columns):
# customer_id    251 non-null int64
# total_bill     251 non-null float64
# tip            248 non-null float64
# sex            250 non-null object
# smoker         250 non-null object
# day            251 non-null object
# time           251 non-null object
# size           250 non-null float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 15.8+ KB

# %% [markdown]
# ## Indexing, selection
# - 데이터 검색하기

# %% [markdown]
# ### column 이름으로 접근

# %%
tips[["total_bill", 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# 5         25.29  4.71
# 6          8.77  2.00
# 7         26.88  3.12
# 8         15.04  1.96
# 9         14.78  3.23
# 10        10.27  1.71
# 11        35.26  5.00
# 12        15.42  1.57
# 13        18.43  3.00
# 14        14.83  3.02
# 15        21.58  3.92
# 16        10.33  1.67
# 17        16.29  3.71
# 18        16.97  3.50
# 19        20.65  3.35
# 20        17.92  4.08
# 21        20.29  2.75
# 22        15.77  2.23
# 23        39.42  7.58
# 24        19.82  3.18
# 25        17.81  2.34
# 26        13.37  2.00
# 27        12.69  2.00
# 28        21.70  4.30
# 29        19.65  3.00
# ..          ...   ...
# 221       28.17  6.50
# 222       12.90  1.10
# 223       28.15  3.00
# 224       11.59  1.50
# 225        7.74  1.44
# 226       30.14  3.09
# 227       12.16  2.20
# 228       13.42  3.48
# 229        8.58  1.92
# 230       15.98  3.00
# 231       13.42  1.58
# 232       16.27  2.50
# 233       10.09  2.00
# 234       20.45  3.00
# 235       13.28  2.72
# 236       22.12  2.88
# 237       24.01  2.00
# 238       15.69  3.00
# 239       11.61  3.39
# 240       10.77  1.47
# 241       15.53  3.00
# 242       10.07  1.25
# 243       12.60  1.00
# 244       32.83  1.17
# 245       35.83  4.67
# 246       29.03  5.92
# 247       27.18  2.00
# 248       22.67  2.00
# 249       17.82  1.75
# 250       18.78  3.00
#
# [251 rows x 2 columns]

# %%
tips.day
# Out:
# 0           Sun
# 1        Sunday
# 2           Sun
# 3           Sun
# 4           Sun
# 5           Sun
# 6           Sun
# 7        Sunday
# 8           Sun
# 9           Sun
# 10          Sun
# 11       Sunday
# 12          Sun
# 13          Sun
# 14       Sunday
# 15          Sun
# 16       Sunday
# 17       Sunday
# 18          Sun
# 19     Saturday
# 20          Sat
# 21          Sat
# 22          Sat
# 23          Sat
# 24          Sat
# 25          Sat
# 26          Sat
# 27     saturday
# 28          Sat
# 29          Sat
#          ...
# 221         Sat
# 222         Sat
# 223         Sat
# 224         Sat
# 225         Sat
# 226         Sat
# 227         Fri
# 228         Fri
# 229      Friday
# 230      Friday
# 231         Fri
# 232         Fri
# 233         Fri
# 234         Sat
# 235         Sat
# 236         Sat
# 237         Sat
# 238         Sat
# 239         Sat
# 240         Sat
# 241         Sat
# 242         Sat
# 243         Sat
# 244         Sat
# 245         Sat
# 246         Sat
# 247         Sat
# 248         Sat
# 249         Sat
# 250        Thur
# Name: day, Length: 251, dtype: object

# %%
tips.day.values
# Out:
# array(['Sun', 'Sunday', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sunday',
#        'Sun', 'Sun', 'Sun', 'Sunday', 'Sun', 'Sun', 'Sunday', 'Sun',
#        'Sunday', 'Sunday', 'Sun', 'Saturday', 'Sat', 'Sat', 'Sat', 'Sat',
#        'Sat', 'Sat', 'Sat', 'saturday', 'Sat', 'Sat', 'saturday', 'Sat',
#        'Sat', 'Sat.', 'Sat', 'Sat.', 'Sat', 'Sat', 'Sat', 'Saturday',
#        'Saturday', 'Sun', 'Sun', 'Sun', 'Sunday', 'Sunday', 'Sunday',
#        'Sun', 'Sun', 'Sun', 'Sun', 'Sun.', 'Sun.', 'Sun.', 'Sun', 'Sun',
#        'Sun', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat.',
#        'Saturday', 'Sat', 'Saturday', 'Sat', 'Sat', 'Thur', 'Sat', 'Sat',
#        'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Thur',
#        'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur',
#        'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Fri', 'Fri',
#        'Friday', 'friday', 'Fri', 'Fri', 'Fri', 'Friday', 'Fri', 'Fri',
#        'Fri', 'Friday', 'Sat', 'Sat', 'Sat', 'Fri', 'Sat', 'Sat', 'Sat',
#        'Sat', 'Sat', 'Sat', 'Saturday', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun',
#        'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur',
#        'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur',
#        'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur',
#        'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur',
#        'Thur', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun',
#        'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun',
#        'Sun', 'Sun', 'Sat', 'Sat', 'Sat', 'Sat', 'Sun', 'Sun', 'Sun',
#        'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun',
#        'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Sun', 'Thur', 'Thur',
#        'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Thur',
#        'Thur', 'Thur', 'Thur', 'Thur', 'Thur', 'Sat', 'Sat', 'Sat', 'Sat',
#        'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat',
#        'Sat', 'Fri', 'Fri', 'Friday', 'Friday', 'Fri', 'Fri', 'Fri',
#        'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat',
#        'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Thur'],
#       dtype=object)

# %% [markdown]
# ### index로 접근

# %%
tips[0:7]
# Out:
#    customer_id  total_bill   tip     sex smoker     day    time  size
# 0            1       16.99  1.01  Female     No     Sun  Dinner   2.0
# 1            2       10.34  1.66    Male     No  Sunday  Dinner   3.0
# 2            3       21.01  3.50    Male     No     Sun  Dinner   3.0
# 3            4       23.68  3.31    Male     No     Sun  Dinner   2.0
# 4            5       24.59  3.61  Female     No     Sun  Dinner   4.0
# 5            6       25.29  4.71    Male     No     Sun  Dinner   4.0
# 6            7        8.77  2.00    Male     No     Sun  Dinner   2.0

# %% [markdown]
# ### loc, iloc
# - loc: 라벨 이름으로 검색 (원래 인덱스가 정수인 경우는 예외적으로 허용)
# - iloc: 정숫값 인덱스로 검색<br>
#
# *참고: https://datascienceschool.net/view-notebook/704731b41f794b8ea00768f5b0904512/

# %%
tips.loc[:, ['tip', 'sex']]
# tips.loc[:, [1, 2, 3]] -> 에러 발생
# Out:
#       tip     sex
# 0    1.01  Female
# 1    1.66    Male
# 2    3.50    Male
# 3    3.31    Male
# 4    3.61  Female
# 5    4.71    Male
# 6    2.00    Male
# 7    3.12    Male
# 8    1.96    Male
# 9    3.23    Male
# 10   1.71    Male
# 11   5.00  Female
# 12   1.57    Male
# 13   3.00    Male
# 14   3.02  Female
# 15   3.92    Male
# 16   1.67  Female
# 17   3.71    Male
# 18   3.50  Female
# 19   3.35    Male
# 20   4.08    Male
# 21   2.75  Female
# 22   2.23  Female
# 23   7.58    Male
# 24   3.18    Male
# 25   2.34    Male
# 26   2.00    Male
# 27   2.00    Male
# 28   4.30    Male
# 29   3.00  Female
# ..    ...     ...
# 221  6.50  Female
# 222  1.10  Female
# 223  3.00    Male
# 224  1.50    Male
# 225  1.44    Male
# 226  3.09  Female
# 227  2.20    Male
# 228  3.48  Female
# 229  1.92    Male
# 230  3.00  Female
# 231  1.58    Male
# 232  2.50  Female
# 233  2.00  Female
# 234  3.00    Male
# 235  2.72    Male
# 236  2.88  Female
# 237  2.00    Male
# 238  3.00    Male
# 239  3.39    Male
# 240  1.47    Male
# 241  3.00    Male
# 242  1.25    Male
# 243  1.00    Male
# 244  1.17    Male
# 245  4.67  Female
# 246  5.92    Male
# 247  2.00  Female
# 248  2.00    Male
# 249  1.75    Male
# 250  3.00  Female
#
# [251 rows x 2 columns]

# %%
tips.iloc[[2, 5, 7], 1:4]
# Out:
#    total_bill   tip   sex
# 2       21.01  3.50  Male
# 5       25.29  4.71  Male
# 7       26.88  3.12  Male

# %% [markdown]
# ## Exploring data

# %% [markdown]
# ### 데이터 구성 파악

# %%
tips.columns
# Out:
# Index(['customer_id', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
tips.sex.unique()
# Out:
# array(['Female', 'Male', nan], dtype=object)

# %%
tips.day.unique()
# Out:
# array(['Sun', 'Sunday', 'Saturday', 'Sat', 'saturday', 'Sat.', 'Sun.',
#        'Thur', 'Fri', 'Friday', 'friday'], dtype=object)

# %%
tips.sex.value_counts()
# Out:
# Male      159
# Female     91
# Name: sex, dtype: int64

# %% [markdown]
# ### Sorting

# %%
tips.sort_values('total_bill', ascending=False)
# Out:
#      customer_id  total_bill    tip     sex smoker       day    time  size
# 177          175       50.81  10.00    Male    Yes       Sat  Dinner   3.0
# 110          109       48.68    NaN  Female    Yes       Fri  Dinner   NaN
# 219          217       48.33   9.00    Male     No       Sat  Dinner   4.0
# 60            60       48.27   6.73    Male     No       Sat  Dinner   4.0
# 163          161       48.17   5.00    Male     No       Sun  Dinner   6.0
# 189          187       45.35   3.50    Male    Yes       Sun  Dinner   3.0
# 107          106       44.30   2.50  Female    Yes       Sat  Dinner   3.0
# 204          202       43.11   5.00  Female    Yes      Thur   Lunch   4.0
# 148          147       41.19   5.00    Male     No      Thur   Lunch   5.0
# 191          189       40.55   3.00    Male    Yes       Sun  Dinner   2.0
# 100           99       40.17   4.73    Male    Yes       Fri  Dinner   4.0
# 23            24       39.42   7.58    Male     No       Sat  Dinner   4.0
# 214          212       38.73   3.00    Male    Yes       Sat  Dinner   4.0
# 118          117       38.07   4.00    Male     No       Sun  Dinner   3.0
# 57            57       38.01   3.00    Male    Yes       Sat  Dinner   4.0
# 245          243       35.83   4.67  Female     No       Sat  Dinner   3.0
# 11            12       35.26   5.00  Female     No    Sunday  Dinner   4.0
# 89            89       34.83   5.17  Female     No      Thur   Lunch   4.0
# 90            89       34.83   5.17  Female     No      Thur   Lunch   4.0
# 53            53       34.81   5.20  Female     No      Sun.  Dinner   4.0
# 187          185       34.65   3.68    Male    Yes       Sun  Dinner   4.0
# 186          184       34.63   3.55    Male    Yes       Sun  Dinner   2.0
# 147          146       34.30   6.70    Male     No      Thur   Lunch   6.0
# 182          180       32.90   3.11    Male    Yes       Sun  Dinner   2.0
# 244          242       32.83   1.17    Male    Yes       Sat  Dinner   2.0
# 86            86       32.68   5.00    Male    Yes      Thur   Lunch   2.0
# 47            48       32.40   6.00    Male     No       Sun  Dinner   4.0
# 180          178       31.85   3.18    Male    Yes       Sun  Dinner   2.0
# 174          172       31.71   4.50    Male     No       Sun  Dinner   4.0
# 39            40       31.27   5.00    Male     No  Saturday  Dinner   3.0
# ..           ...         ...    ...     ...    ...       ...     ...   ...
# 123          122       10.65   1.50  Female     No      Thur   Lunch   2.0
# 176          174       10.63   2.00  Female    Yes       Sat  Dinner   2.0
# 175          173       10.59   1.61  Female    Yes       Sat  Dinner   2.0
# 78            78       10.51   1.25    Male     No       Sat  Dinner   2.0
# 1              2       10.34   1.66    Male     No    Sunday  Dinner   3.0
# 203          201       10.34   2.00    Male    Yes      Thur   Lunch   2.0
# 142          141       10.33   2.00  Female     No      Thur   Lunch   2.0
# 16            17       10.33   1.67  Female     No    Sunday  Dinner   3.0
# 52            52       10.29   2.60  Female     No      Sun.  Dinner   2.0
# 10            11       10.27   1.71    Male     No       Sun  Dinner   2.0
# 233          231       10.09   2.00  Female    Yes       Fri   Lunch   2.0
# 242          240       10.07   1.25    Male     No       Sat  Dinner   2.0
# 85            85       10.07   1.83  Female     No      Thur   Lunch   1.0
# 54            54        9.94   1.56    Male     No       Sun  Dinner   2.0
# 154          153        9.78   1.73    Male     No      Thur   Lunch   2.0
# 43            44        9.68   1.32    Male     No       Sun  Dinner   2.0
# 185          183        9.60   4.00  Female    Yes       Sun  Dinner   2.0
# 30            31        9.55   1.45    Male     No  saturday  Dinner   2.0
# 6              7        8.77   2.00    Male     No       Sun  Dinner   2.0
# 229          227        8.58   1.92    Male    Yes    Friday   Lunch   1.0
# 132          131        8.52   1.48    Male     No      Thur   Lunch   2.0
# 141          140        8.51   1.25  Female     No      Thur   Lunch   2.0
# 151          150        8.35   1.50  Female     No      Thur   Lunch   2.0
# 225          223        7.74   1.44    Male    Yes       Sat  Dinner   2.0
# 202          200        7.56   1.44    Male     No      Thur   Lunch   2.0
# 155          154        7.51   2.00    Male     No      Thur   Lunch   2.0
# 179          177        7.25   5.15    Male    Yes       Sun  Dinner   2.0
# 117          116        7.25   1.00  Female     No  Saturday  Dinner   1.0
# 97            96        5.75   1.00  Female    Yes    Friday  Dinner   2.0
# 70            70        3.07   1.00  Female    Yes       Sat  Dinner   1.0
#
# [251 rows x 8 columns]

# %% [markdown]
# ### filtering
# - 특정 조건을 만족하는 데이터만 추출

# %% [markdown]
# 흡연자가 없었던 경우만 검색

# %%
tips[tips.smoker == 'No']
# Out:
#      customer_id  total_bill   tip     sex smoker       day    time  size
# 0              1       16.99  1.01  Female     No       Sun  Dinner   2.0
# 1              2       10.34  1.66    Male     No    Sunday  Dinner   3.0
# 2              3       21.01  3.50    Male     No       Sun  Dinner   3.0
# 3              4       23.68  3.31    Male     No       Sun  Dinner   2.0
# 4              5       24.59  3.61  Female     No       Sun  Dinner   4.0
# 5              6       25.29  4.71    Male     No       Sun  Dinner   4.0
# 6              7        8.77  2.00    Male     No       Sun  Dinner   2.0
# 7              8       26.88  3.12    Male     No    Sunday  Dinner   4.0
# 8              9       15.04  1.96    Male     No       Sun  Dinner   2.0
# 9             10       14.78  3.23    Male     No       Sun  Dinner   2.0
# 10            11       10.27  1.71    Male     No       Sun  Dinner   2.0
# 11            12       35.26  5.00  Female     No    Sunday  Dinner   4.0
# 12            13       15.42  1.57    Male     No       Sun  Dinner   2.0
# 13            14       18.43  3.00    Male     No       Sun  Dinner   4.0
# 14            15       14.83  3.02  Female     No    Sunday  Dinner   2.0
# 15            16       21.58  3.92    Male     No       Sun  Dinner   2.0
# 16            17       10.33  1.67  Female     No    Sunday  Dinner   3.0
# 17            18       16.29  3.71    Male     No    Sunday  Dinner   3.0
# 18            19       16.97  3.50  Female     No       Sun  Dinner   3.0
# 19            20       20.65  3.35    Male     No  Saturday  Dinner   3.0
# 20            21       17.92  4.08    Male     No       Sat  Dinner   2.0
# 21            22       20.29  2.75  Female     No       Sat  Dinner   2.0
# 22            23       15.77  2.23  Female     No       Sat  Dinner   2.0
# 23            24       39.42  7.58    Male     No       Sat  Dinner   4.0
# 24            25       19.82  3.18    Male     No       Sat  Dinner   2.0
# 25            26       17.81  2.34    Male     No       Sat  Dinner   4.0
# 26            27       13.37  2.00    Male     No       Sat  Dinner   2.0
# 27            28       12.69  2.00    Male     No  saturday  Dinner   2.0
# 28            29       21.70  4.30    Male     No       Sat  Dinner   2.0
# 29            30       19.65  3.00  Female     No       Sat  Dinner   2.0
# ..           ...         ...   ...     ...    ...       ...     ...   ...
# 157          156       13.13  2.00    Male     No       Sun  Dinner   2.0
# 158          157       17.26  2.74  Female     No       Sun  Dinner   3.0
# 159          157       17.26  2.74    Male     No       Sun  Dinner   3.0
# 160          158       24.55  2.00    Male     No       Sun  Dinner   4.0
# 161          159       19.77  2.00    Male     No       Sun  Dinner   4.0
# 162          160       29.85  5.14  Female     No       Sun  Dinner   5.0
# 163          161       48.17  5.00    Male     No       Sun  Dinner   6.0
# 164          162       25.00  3.75  Female     No       Sun  Dinner   4.0
# 165          163       13.39  2.61  Female     No       Sun  Dinner   2.0
# 166          164       16.49  2.00    Male     No       Sun  Dinner   4.0
# 167          165       21.50  3.50    Male     No       Sun  Dinner   4.0
# 168          166       12.66  2.50    Male     No       Sun  Dinner   2.0
# 169          167       16.21  2.00  Female     No       Sun  Dinner   3.0
# 170          168       13.81  2.00    Male     No       Sun  Dinner   2.0
# 172          170       24.52  3.48    Male     No       Sun  Dinner   3.0
# 173          171       20.76  2.24    Male     No       Sun  Dinner   2.0
# 174          172       31.71  4.50    Male     No       Sun  Dinner   4.0
# 192          190       20.69  5.00    Male     No       Sun  Dinner   5.0
# 202          200        7.56  1.44    Male     No      Thur   Lunch   2.0
# 219          217       48.33  9.00    Male     No       Sat  Dinner   4.0
# 230          228       15.98  3.00  Female     No    Friday   Lunch   3.0
# 234          232       20.45  3.00    Male     No       Sat  Dinner   4.0
# 235          233       13.28  2.72    Male     No       Sat  Dinner   2.0
# 239          237       11.61  3.39    Male     No       Sat  Dinner   2.0
# 240          238       10.77  1.47    Male     No       Sat  Dinner   2.0
# 242          240       10.07  1.25    Male     No       Sat  Dinner   2.0
# 245          243       35.83  4.67  Female     No       Sat  Dinner   3.0
# 246          244       29.03  5.92    Male     No       Sat  Dinner   3.0
# 249          247       17.82  1.75    Male     No       Sat  Dinner   2.0
# 250          248       18.78  3.00  Female     No      Thur  Dinner   2.0
#
# [155 rows x 8 columns]

# %% [markdown]
# 총 지출액이 15달러 이상이었던 경우만 검색

# %%
tips[tips['total_bill'] >= 15]
# Out:
#      customer_id  total_bill   tip     sex smoker       day    time  size
# 0              1       16.99  1.01  Female     No       Sun  Dinner   2.0
# 2              3       21.01  3.50    Male     No       Sun  Dinner   3.0
# 3              4       23.68  3.31    Male     No       Sun  Dinner   2.0
# 4              5       24.59  3.61  Female     No       Sun  Dinner   4.0
# 5              6       25.29  4.71    Male     No       Sun  Dinner   4.0
# 7              8       26.88  3.12    Male     No    Sunday  Dinner   4.0
# 8              9       15.04  1.96    Male     No       Sun  Dinner   2.0
# 11            12       35.26  5.00  Female     No    Sunday  Dinner   4.0
# 12            13       15.42  1.57    Male     No       Sun  Dinner   2.0
# 13            14       18.43  3.00    Male     No       Sun  Dinner   4.0
# 15            16       21.58  3.92    Male     No       Sun  Dinner   2.0
# 17            18       16.29  3.71    Male     No    Sunday  Dinner   3.0
# 18            19       16.97  3.50  Female     No       Sun  Dinner   3.0
# 19            20       20.65  3.35    Male     No  Saturday  Dinner   3.0
# 20            21       17.92  4.08    Male     No       Sat  Dinner   2.0
# 21            22       20.29  2.75  Female     No       Sat  Dinner   2.0
# 22            23       15.77  2.23  Female     No       Sat  Dinner   2.0
# 23            24       39.42  7.58    Male     No       Sat  Dinner   4.0
# 24            25       19.82  3.18    Male     No       Sat  Dinner   2.0
# 25            26       17.81  2.34    Male     No       Sat  Dinner   4.0
# 28            29       21.70  4.30    Male     No       Sat  Dinner   2.0
# 29            30       19.65  3.00  Female     No       Sat  Dinner   2.0
# 31            32       18.35  2.50    Male     No       Sat  Dinner   4.0
# 32            33       15.06  3.00  Female     No       Sat  Dinner   2.0
# 33            34       20.69  2.45  Female     No      Sat.  Dinner   4.0
# 34            35       17.78  3.27    Male     No       Sat  Dinner   2.0
# 35            36       24.06  3.60    Male     No      Sat.  Dinner   3.0
# 36            37       16.31  2.00    Male     No       Sat  Dinner   3.0
# 37            38       16.93  3.07  Female     No       Sat  Dinner   3.0
# 38            39       18.69  2.31    Male     No       Sat  Dinner   3.0
# ..           ...         ...   ...     ...    ...       ...     ...   ...
# 200          198       15.48  2.02    Male    Yes      Thur   Lunch   2.0
# 201          199       16.58  4.00    Male    Yes      Thur   Lunch   2.0
# 204          202       43.11  5.00  Female    Yes      Thur   Lunch   4.0
# 207          205       18.71  4.00    Male    Yes      Thur   Lunch   3.0
# 210          208       16.40  2.50  Female    Yes      Thur   Lunch   2.0
# 211          209       20.53  4.00    Male    Yes      Thur   Lunch   4.0
# 212          210       16.47  3.23  Female    Yes      Thur   Lunch   3.0
# 213          211       26.59  3.41    Male    Yes       Sat  Dinner   3.0
# 214          212       38.73  3.00    Male    Yes       Sat  Dinner   4.0
# 215          213       24.27  2.03    Male    Yes       Sat  Dinner   2.0
# 217          215       30.06  2.00    Male    Yes       Sat  Dinner   3.0
# 218          216       25.89  5.16    Male    Yes       Sat  Dinner   4.0
# 219          217       48.33  9.00    Male     No       Sat  Dinner   4.0
# 221          219       28.17  6.50  Female    Yes       Sat  Dinner   3.0
# 223          221       28.15  3.00    Male    Yes       Sat  Dinner   5.0
# 226          224       30.14  3.09  Female    Yes       Sat  Dinner   4.0
# 230          228       15.98  3.00  Female     No    Friday   Lunch   3.0
# 232          230       16.27  2.50  Female    Yes       Fri   Lunch   2.0
# 234          232       20.45  3.00    Male     No       Sat  Dinner   4.0
# 236          234       22.12  2.88  Female    Yes       Sat  Dinner   2.0
# 237          235       24.01  2.00    Male    Yes       Sat  Dinner   4.0
# 238          236       15.69  3.00    Male    Yes       Sat  Dinner   3.0
# 241          239       15.53  3.00    Male    Yes       Sat  Dinner   2.0
# 244          242       32.83  1.17    Male    Yes       Sat  Dinner   2.0
# 245          243       35.83  4.67  Female     No       Sat  Dinner   3.0
# 246          244       29.03  5.92    Male     No       Sat  Dinner   3.0
# 247          245       27.18  2.00  Female    Yes       Sat  Dinner   2.0
# 248          246       22.67  2.00    Male    Yes       Sat  Dinner   2.0
# 249          247       17.82  1.75    Male     No       Sat  Dinner   2.0
# 250          248       18.78  3.00  Female     No      Thur  Dinner   2.0
#
# [171 rows x 8 columns]

# %% [markdown]
# ### 실습 1) loc 또는 iloc을 이용하여 '흡연자이면서 팁을 5달러 이상 낸 고객'의 'size' 값의 구성을 파악하여라.

# %%
tips.loc[(tips['smoker']=='Yes')&(tips['tip']>=5),['size']]
# Out:
#      size
# 76    2.0
# 86    2.0
# 177   3.0
# 179   2.0
# 188   2.0
# 190   4.0
# 204   4.0
# 218   4.0
# 221   3.0

# %% [markdown]
# ## Handling missing data

# %% [markdown]
# #### find missing data
# *참고: https://stackoverflow.com/questions/29530232/how-to-check-if-any-value-is-nan-in-a-pandas-dataframe

# %%
tips.isnull()
# Out:
#      customer_id  total_bill    tip    sex  smoker    day   time   size
# 0          False       False  False  False   False  False  False  False
# 1          False       False  False  False   False  False  False  False
# 2          False       False  False  False   False  False  False  False
# 3          False       False  False  False   False  False  False  False
# 4          False       False  False  False   False  False  False  False
# 5          False       False  False  False   False  False  False  False
# 6          False       False  False  False   False  False  False  False
# 7          False       False  False  False   False  False  False  False
# 8          False       False  False  False   False  False  False  False
# 9          False       False  False  False   False  False  False  False
# 10         False       False  False  False   False  False  False  False
# 11         False       False  False  False   False  False  False  False
# 12         False       False  False  False   False  False  False  False
# 13         False       False  False  False   False  False  False  False
# 14         False       False  False  False   False  False  False  False
# 15         False       False  False  False   False  False  False  False
# 16         False       False  False  False   False  False  False  False
# 17         False       False  False  False   False  False  False  False
# 18         False       False  False  False   False  False  False  False
# 19         False       False  False  False   False  False  False  False
# 20         False       False  False  False   False  False  False  False
# 21         False       False  False  False   False  False  False  False
# 22         False       False  False  False   False  False  False  False
# 23         False       False  False  False   False  False  False  False
# 24         False       False  False  False   False  False  False  False
# 25         False       False  False  False   False  False  False  False
# 26         False       False  False  False   False  False  False  False
# 27         False       False  False  False   False  False  False  False
# 28         False       False  False  False   False  False  False  False
# 29         False       False  False  False   False  False  False  False
# ..           ...         ...    ...    ...     ...    ...    ...    ...
# 221        False       False  False  False   False  False  False  False
# 222        False       False  False  False   False  False  False  False
# 223        False       False  False  False   False  False  False  False
# 224        False       False  False  False   False  False  False  False
# 225        False       False  False  False   False  False  False  False
# 226        False       False  False  False   False  False  False  False
# 227        False       False  False  False   False  False  False  False
# 228        False       False  False  False   False  False  False  False
# 229        False       False  False  False   False  False  False  False
# 230        False       False  False  False   False  False  False  False
# 231        False       False  False  False   False  False  False  False
# 232        False       False  False  False   False  False  False  False
# 233        False       False  False  False   False  False  False  False
# 234        False       False  False  False   False  False  False  False
# 235        False       False  False  False   False  False  False  False
# 236        False       False  False  False   False  False  False  False
# 237        False       False  False  False   False  False  False  False
# 238        False       False  False  False   False  False  False  False
# 239        False       False  False  False   False  False  False  False
# 240        False       False  False  False   False  False  False  False
# 241        False       False  False  False   False  False  False  False
# 242        False       False  False  False   False  False  False  False
# 243        False       False  False  False   False  False  False  False
# 244        False       False  False  False   False  False  False  False
# 245        False       False  False  False   False  False  False  False
# 246        False       False  False  False   False  False  False  False
# 247        False       False  False  False   False  False  False  False
# 248        False       False  False  False   False  False  False  False
# 249        False       False  False  False   False  False  False  False
# 250        False       False  False  False   False  False  False  False
#
# [251 rows x 8 columns]

# %%
tips.notnull()
# Out:
#      customer_id  total_bill   tip   sex  smoker   day  time  size
# 0           True        True  True  True    True  True  True  True
# 1           True        True  True  True    True  True  True  True
# 2           True        True  True  True    True  True  True  True
# 3           True        True  True  True    True  True  True  True
# 4           True        True  True  True    True  True  True  True
# 5           True        True  True  True    True  True  True  True
# 6           True        True  True  True    True  True  True  True
# 7           True        True  True  True    True  True  True  True
# 8           True        True  True  True    True  True  True  True
# 9           True        True  True  True    True  True  True  True
# 10          True        True  True  True    True  True  True  True
# 11          True        True  True  True    True  True  True  True
# 12          True        True  True  True    True  True  True  True
# 13          True        True  True  True    True  True  True  True
# 14          True        True  True  True    True  True  True  True
# 15          True        True  True  True    True  True  True  True
# 16          True        True  True  True    True  True  True  True
# 17          True        True  True  True    True  True  True  True
# 18          True        True  True  True    True  True  True  True
# 19          True        True  True  True    True  True  True  True
# 20          True        True  True  True    True  True  True  True
# 21          True        True  True  True    True  True  True  True
# 22          True        True  True  True    True  True  True  True
# 23          True        True  True  True    True  True  True  True
# 24          True        True  True  True    True  True  True  True
# 25          True        True  True  True    True  True  True  True
# 26          True        True  True  True    True  True  True  True
# 27          True        True  True  True    True  True  True  True
# 28          True        True  True  True    True  True  True  True
# 29          True        True  True  True    True  True  True  True
# ..           ...         ...   ...   ...     ...   ...   ...   ...
# 221         True        True  True  True    True  True  True  True
# 222         True        True  True  True    True  True  True  True
# 223         True        True  True  True    True  True  True  True
# 224         True        True  True  True    True  True  True  True
# 225         True        True  True  True    True  True  True  True
# 226         True        True  True  True    True  True  True  True
# 227         True        True  True  True    True  True  True  True
# 228         True        True  True  True    True  True  True  True
# 229         True        True  True  True    True  True  True  True
# 230         True        True  True  True    True  True  True  True
# 231         True        True  True  True    True  True  True  True
# 232         True        True  True  True    True  True  True  True
# 233         True        True  True  True    True  True  True  True
# 234         True        True  True  True    True  True  True  True
# 235         True        True  True  True    True  True  True  True
# 236         True        True  True  True    True  True  True  True
# 237         True        True  True  True    True  True  True  True
# 238         True        True  True  True    True  True  True  True
# 239         True        True  True  True    True  True  True  True
# 240         True        True  True  True    True  True  True  True
# 241         True        True  True  True    True  True  True  True
# 242         True        True  True  True    True  True  True  True
# 243         True        True  True  True    True  True  True  True
# 244         True        True  True  True    True  True  True  True
# 245         True        True  True  True    True  True  True  True
# 246         True        True  True  True    True  True  True  True
# 247         True        True  True  True    True  True  True  True
# 248         True        True  True  True    True  True  True  True
# 249         True        True  True  True    True  True  True  True
# 250         True        True  True  True    True  True  True  True
#
# [251 rows x 8 columns]

# %% [markdown]
# 특정 column의 null 값 찾기

# %%
tips.isnull().any()
# Out:
# customer_id    False
# total_bill     False
# tip             True
# sex             True
# smoker          True
# day            False
# time           False
# size            True
# dtype: bool

# %%
tips.isnull().sum() # sum 함수는 summarizing and computing descriptive statistics  참조
# Out:
# customer_id    0
# total_bill     0
# tip            3
# sex            1
# smoker         1
# day            0
# time           0
# size           1
# dtype: int64

# %% [markdown]
# 특정 row의 null 값 찾기

# %%
tips[tips.isnull().any(axis=1)]
# Out:
#      customer_id  total_bill  tip     sex smoker   day    time  size
# 61            61       28.03  2.1  Female    NaN   Sat   Lunch   2.0
# 69            69       15.20  NaN    Male    Yes  Thur  Dinner   4.0
# 87            87       27.10  NaN     NaN     No  Thur   Lunch   3.0
# 110          109       48.68  NaN  Female    Yes   Fri  Dinner   NaN

# %% [markdown]
# #### Filtering out missing data

# %%
tips.dropna() # how='all' 조건을 넣어줄 경우 모든 값이 Null인 row만 제거
# Out:
#      customer_id  total_bill   tip     sex smoker       day    time  size
# 0              1       16.99  1.01  Female     No       Sun  Dinner   2.0
# 1              2       10.34  1.66    Male     No    Sunday  Dinner   3.0
# 2              3       21.01  3.50    Male     No       Sun  Dinner   3.0
# 3              4       23.68  3.31    Male     No       Sun  Dinner   2.0
# 4              5       24.59  3.61  Female     No       Sun  Dinner   4.0
# 5              6       25.29  4.71    Male     No       Sun  Dinner   4.0
# 6              7        8.77  2.00    Male     No       Sun  Dinner   2.0
# 7              8       26.88  3.12    Male     No    Sunday  Dinner   4.0
# 8              9       15.04  1.96    Male     No       Sun  Dinner   2.0
# 9             10       14.78  3.23    Male     No       Sun  Dinner   2.0
# 10            11       10.27  1.71    Male     No       Sun  Dinner   2.0
# 11            12       35.26  5.00  Female     No    Sunday  Dinner   4.0
# 12            13       15.42  1.57    Male     No       Sun  Dinner   2.0
# 13            14       18.43  3.00    Male     No       Sun  Dinner   4.0
# 14            15       14.83  3.02  Female     No    Sunday  Dinner   2.0
# 15            16       21.58  3.92    Male     No       Sun  Dinner   2.0
# 16            17       10.33  1.67  Female     No    Sunday  Dinner   3.0
# 17            18       16.29  3.71    Male     No    Sunday  Dinner   3.0
# 18            19       16.97  3.50  Female     No       Sun  Dinner   3.0
# 19            20       20.65  3.35    Male     No  Saturday  Dinner   3.0
# 20            21       17.92  4.08    Male     No       Sat  Dinner   2.0
# 21            22       20.29  2.75  Female     No       Sat  Dinner   2.0
# 22            23       15.77  2.23  Female     No       Sat  Dinner   2.0
# 23            24       39.42  7.58    Male     No       Sat  Dinner   4.0
# 24            25       19.82  3.18    Male     No       Sat  Dinner   2.0
# 25            26       17.81  2.34    Male     No       Sat  Dinner   4.0
# 26            27       13.37  2.00    Male     No       Sat  Dinner   2.0
# 27            28       12.69  2.00    Male     No  saturday  Dinner   2.0
# 28            29       21.70  4.30    Male     No       Sat  Dinner   2.0
# 29            30       19.65  3.00  Female     No       Sat  Dinner   2.0
# ..           ...         ...   ...     ...    ...       ...     ...   ...
# 221          219       28.17  6.50  Female    Yes       Sat  Dinner   3.0
# 222          220       12.90  1.10  Female    Yes       Sat  Dinner   2.0
# 223          221       28.15  3.00    Male    Yes       Sat  Dinner   5.0
# 224          222       11.59  1.50    Male    Yes       Sat  Dinner   2.0
# 225          223        7.74  1.44    Male    Yes       Sat  Dinner   2.0
# 226          224       30.14  3.09  Female    Yes       Sat  Dinner   4.0
# 227          225       12.16  2.20    Male    Yes       Fri   Lunch   2.0
# 228          226       13.42  3.48  Female    Yes       Fri   Lunch   2.0
# 229          227        8.58  1.92    Male    Yes    Friday   Lunch   1.0
# 230          228       15.98  3.00  Female     No    Friday   Lunch   3.0
# 231          229       13.42  1.58    Male    Yes       Fri   Lunch   2.0
# 232          230       16.27  2.50  Female    Yes       Fri   Lunch   2.0
# 233          231       10.09  2.00  Female    Yes       Fri   Lunch   2.0
# 234          232       20.45  3.00    Male     No       Sat  Dinner   4.0
# 235          233       13.28  2.72    Male     No       Sat  Dinner   2.0
# 236          234       22.12  2.88  Female    Yes       Sat  Dinner   2.0
# 237          235       24.01  2.00    Male    Yes       Sat  Dinner   4.0
# 238          236       15.69  3.00    Male    Yes       Sat  Dinner   3.0
# 239          237       11.61  3.39    Male     No       Sat  Dinner   2.0
# 240          238       10.77  1.47    Male     No       Sat  Dinner   2.0
# 241          239       15.53  3.00    Male    Yes       Sat  Dinner   2.0
# 242          240       10.07  1.25    Male     No       Sat  Dinner   2.0
# 243          241       12.60  1.00    Male    Yes       Sat  Dinner   2.0
# 244          242       32.83  1.17    Male    Yes       Sat  Dinner   2.0
# 245          243       35.83  4.67  Female     No       Sat  Dinner   3.0
# 246          244       29.03  5.92    Male     No       Sat  Dinner   3.0
# 247          245       27.18  2.00  Female    Yes       Sat  Dinner   2.0
# 248          246       22.67  2.00    Male    Yes       Sat  Dinner   2.0
# 249          247       17.82  1.75    Male     No       Sat  Dinner   2.0
# 250          248       18.78  3.00  Female     No      Thur  Dinner   2.0
#
# [247 rows x 8 columns]

# %% [markdown]
# #### Filling in Missing Data
# * 참고: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html

# %% [markdown]
# ### 실습2) dropna 함수를 사용하지 않고 null 값을 제거하여라.

# %%
tips[tips.notnull().all(axis=1)]
# Out:
#      customer_id  total_bill   tip     sex smoker       day    time  size
# 0              1       16.99  1.01  Female     No       Sun  Dinner   2.0
# 1              2       10.34  1.66    Male     No    Sunday  Dinner   3.0
# 2              3       21.01  3.50    Male     No       Sun  Dinner   3.0
# 3              4       23.68  3.31    Male     No       Sun  Dinner   2.0
# 4              5       24.59  3.61  Female     No       Sun  Dinner   4.0
# 5              6       25.29  4.71    Male     No       Sun  Dinner   4.0
# 6              7        8.77  2.00    Male     No       Sun  Dinner   2.0
# 7              8       26.88  3.12    Male     No    Sunday  Dinner   4.0
# 8              9       15.04  1.96    Male     No       Sun  Dinner   2.0
# 9             10       14.78  3.23    Male     No       Sun  Dinner   2.0
# 10            11       10.27  1.71    Male     No       Sun  Dinner   2.0
# 11            12       35.26  5.00  Female     No    Sunday  Dinner   4.0
# 12            13       15.42  1.57    Male     No       Sun  Dinner   2.0
# 13            14       18.43  3.00    Male     No       Sun  Dinner   4.0
# 14            15       14.83  3.02  Female     No    Sunday  Dinner   2.0
# 15            16       21.58  3.92    Male     No       Sun  Dinner   2.0
# 16            17       10.33  1.67  Female     No    Sunday  Dinner   3.0
# 17            18       16.29  3.71    Male     No    Sunday  Dinner   3.0
# 18            19       16.97  3.50  Female     No       Sun  Dinner   3.0
# 19            20       20.65  3.35    Male     No  Saturday  Dinner   3.0
# 20            21       17.92  4.08    Male     No       Sat  Dinner   2.0
# 21            22       20.29  2.75  Female     No       Sat  Dinner   2.0
# 22            23       15.77  2.23  Female     No       Sat  Dinner   2.0
# 23            24       39.42  7.58    Male     No       Sat  Dinner   4.0
# 24            25       19.82  3.18    Male     No       Sat  Dinner   2.0
# 25            26       17.81  2.34    Male     No       Sat  Dinner   4.0
# 26            27       13.37  2.00    Male     No       Sat  Dinner   2.0
# 27            28       12.69  2.00    Male     No  saturday  Dinner   2.0
# 28            29       21.70  4.30    Male     No       Sat  Dinner   2.0
# 29            30       19.65  3.00  Female     No       Sat  Dinner   2.0
# ..           ...         ...   ...     ...    ...       ...     ...   ...
# 221          219       28.17  6.50  Female    Yes       Sat  Dinner   3.0
# 222          220       12.90  1.10  Female    Yes       Sat  Dinner   2.0
# 223          221       28.15  3.00    Male    Yes       Sat  Dinner   5.0
# 224          222       11.59  1.50    Male    Yes       Sat  Dinner   2.0
# 225          223        7.74  1.44    Male    Yes       Sat  Dinner   2.0
# 226          224       30.14  3.09  Female    Yes       Sat  Dinner   4.0
# 227          225       12.16  2.20    Male    Yes       Fri   Lunch   2.0
# 228          226       13.42  3.48  Female    Yes       Fri   Lunch   2.0
# 229          227        8.58  1.92    Male    Yes    Friday   Lunch   1.0
# 230          228       15.98  3.00  Female     No    Friday   Lunch   3.0
# 231          229       13.42  1.58    Male    Yes       Fri   Lunch   2.0
# 232          230       16.27  2.50  Female    Yes       Fri   Lunch   2.0
# 233          231       10.09  2.00  Female    Yes       Fri   Lunch   2.0
# 234          232       20.45  3.00    Male     No       Sat  Dinner   4.0
# 235          233       13.28  2.72    Male     No       Sat  Dinner   2.0
# 236          234       22.12  2.88  Female    Yes       Sat  Dinner   2.0
# 237          235       24.01  2.00    Male    Yes       Sat  Dinner   4.0
# 238          236       15.69  3.00    Male    Yes       Sat  Dinner   3.0
# 239          237       11.61  3.39    Male     No       Sat  Dinner   2.0
# 240          238       10.77  1.47    Male     No       Sat  Dinner   2.0
# 241          239       15.53  3.00    Male    Yes       Sat  Dinner   2.0
# 242          240       10.07  1.25    Male     No       Sat  Dinner   2.0
# 243          241       12.60  1.00    Male    Yes       Sat  Dinner   2.0
# 244          242       32.83  1.17    Male    Yes       Sat  Dinner   2.0
# 245          243       35.83  4.67  Female     No       Sat  Dinner   3.0
# 246          244       29.03  5.92    Male     No       Sat  Dinner   3.0
# 247          245       27.18  2.00  Female    Yes       Sat  Dinner   2.0
# 248          246       22.67  2.00    Male    Yes       Sat  Dinner   2.0
# 249          247       17.82  1.75    Male     No       Sat  Dinner   2.0
# 250          248       18.78  3.00  Female     No      Thur  Dinner   2.0
#
# [247 rows x 8 columns]

# %%
tips = tips[tips.notnull().all(axis=1)]

# %% [markdown]
# ## Handling duplicated data

# %%
tips.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# 250    False
# Length: 247, dtype: bool

# %%
tips.drop_duplicates()
# Out:
#      customer_id  total_bill   tip     sex smoker       day    time  size
# 0              1       16.99  1.01  Female     No       Sun  Dinner   2.0
# 1              2       10.34  1.66    Male     No    Sunday  Dinner   3.0
# 2              3       21.01  3.50    Male     No       Sun  Dinner   3.0
# 3              4       23.68  3.31    Male     No       Sun  Dinner   2.0
# 4              5       24.59  3.61  Female     No       Sun  Dinner   4.0
# 5              6       25.29  4.71    Male     No       Sun  Dinner   4.0
# 6              7        8.77  2.00    Male     No       Sun  Dinner   2.0
# 7              8       26.88  3.12    Male     No    Sunday  Dinner   4.0
# 8              9       15.04  1.96    Male     No       Sun  Dinner   2.0
# 9             10       14.78  3.23    Male     No       Sun  Dinner   2.0
# 10            11       10.27  1.71    Male     No       Sun  Dinner   2.0
# 11            12       35.26  5.00  Female     No    Sunday  Dinner   4.0
# 12            13       15.42  1.57    Male     No       Sun  Dinner   2.0
# 13            14       18.43  3.00    Male     No       Sun  Dinner   4.0
# 14            15       14.83  3.02  Female     No    Sunday  Dinner   2.0
# 15            16       21.58  3.92    Male     No       Sun  Dinner   2.0
# 16            17       10.33  1.67  Female     No    Sunday  Dinner   3.0
# 17            18       16.29  3.71    Male     No    Sunday  Dinner   3.0
# 18            19       16.97  3.50  Female     No       Sun  Dinner   3.0
# 19            20       20.65  3.35    Male     No  Saturday  Dinner   3.0
# 20            21       17.92  4.08    Male     No       Sat  Dinner   2.0
# 21            22       20.29  2.75  Female     No       Sat  Dinner   2.0
# 22            23       15.77  2.23  Female     No       Sat  Dinner   2.0
# 23            24       39.42  7.58    Male     No       Sat  Dinner   4.0
# 24            25       19.82  3.18    Male     No       Sat  Dinner   2.0
# 25            26       17.81  2.34    Male     No       Sat  Dinner   4.0
# 26            27       13.37  2.00    Male     No       Sat  Dinner   2.0
# 27            28       12.69  2.00    Male     No  saturday  Dinner   2.0
# 28            29       21.70  4.30    Male     No       Sat  Dinner   2.0
# 29            30       19.65  3.00  Female     No       Sat  Dinner   2.0
# ..           ...         ...   ...     ...    ...       ...     ...   ...
# 221          219       28.17  6.50  Female    Yes       Sat  Dinner   3.0
# 222          220       12.90  1.10  Female    Yes       Sat  Dinner   2.0
# 223          221       28.15  3.00    Male    Yes       Sat  Dinner   5.0
# 224          222       11.59  1.50    Male    Yes       Sat  Dinner   2.0
# 225          223        7.74  1.44    Male    Yes       Sat  Dinner   2.0
# 226          224       30.14  3.09  Female    Yes       Sat  Dinner   4.0
# 227          225       12.16  2.20    Male    Yes       Fri   Lunch   2.0
# 228          226       13.42  3.48  Female    Yes       Fri   Lunch   2.0
# 229          227        8.58  1.92    Male    Yes    Friday   Lunch   1.0
# 230          228       15.98  3.00  Female     No    Friday   Lunch   3.0
# 231          229       13.42  1.58    Male    Yes       Fri   Lunch   2.0
# 232          230       16.27  2.50  Female    Yes       Fri   Lunch   2.0
# 233          231       10.09  2.00  Female    Yes       Fri   Lunch   2.0
# 234          232       20.45  3.00    Male     No       Sat  Dinner   4.0
# 235          233       13.28  2.72    Male     No       Sat  Dinner   2.0
# 236          234       22.12  2.88  Female    Yes       Sat  Dinner   2.0
# 237          235       24.01  2.00    Male    Yes       Sat  Dinner   4.0
# 238          236       15.69  3.00    Male    Yes       Sat  Dinner   3.0
# 239          237       11.61  3.39    Male     No       Sat  Dinner   2.0
# 240          238       10.77  1.47    Male     No       Sat  Dinner   2.0
# 241          239       15.53  3.00    Male    Yes       Sat  Dinner   2.0
# 242          240       10.07  1.25    Male     No       Sat  Dinner   2.0
# 243          241       12.60  1.00    Male    Yes       Sat  Dinner   2.0
# 244          242       32.83  1.17    Male    Yes       Sat  Dinner   2.0
# 245          243       35.83  4.67  Female     No       Sat  Dinner   3.0
# 246          244       29.03  5.92    Male     No       Sat  Dinner   3.0
# 247          245       27.18  2.00  Female    Yes       Sat  Dinner   2.0
# 248          246       22.67  2.00    Male    Yes       Sat  Dinner   2.0
# 249          247       17.82  1.75    Male     No       Sat  Dinner   2.0
# 250          248       18.78  3.00  Female     No      Thur  Dinner   2.0
#
# [246 rows x 8 columns]

# %% [markdown]
# ### 실습2) 중복 값을 확인하고 모두 제거하여라. (함수의 parameter 기능을 읽어보고 활용할 것)
# 1. 중복 값 확인
# 2. 제거

# %%
tips.drop_duplicates()
# Out:
#      customer_id  total_bill   tip     sex smoker       day    time  size
# 0              1       16.99  1.01  Female     No       Sun  Dinner   2.0
# 1              2       10.34  1.66    Male     No    Sunday  Dinner   3.0
# 2              3       21.01  3.50    Male     No       Sun  Dinner   3.0
# 3              4       23.68  3.31    Male     No       Sun  Dinner   2.0
# 4              5       24.59  3.61  Female     No       Sun  Dinner   4.0
# 5              6       25.29  4.71    Male     No       Sun  Dinner   4.0
# 6              7        8.77  2.00    Male     No       Sun  Dinner   2.0
# 7              8       26.88  3.12    Male     No    Sunday  Dinner   4.0
# 8              9       15.04  1.96    Male     No       Sun  Dinner   2.0
# 9             10       14.78  3.23    Male     No       Sun  Dinner   2.0
# 10            11       10.27  1.71    Male     No       Sun  Dinner   2.0
# 11            12       35.26  5.00  Female     No    Sunday  Dinner   4.0
# 12            13       15.42  1.57    Male     No       Sun  Dinner   2.0
# 13            14       18.43  3.00    Male     No       Sun  Dinner   4.0
# 14            15       14.83  3.02  Female     No    Sunday  Dinner   2.0
# 15            16       21.58  3.92    Male     No       Sun  Dinner   2.0
# 16            17       10.33  1.67  Female     No    Sunday  Dinner   3.0
# 17            18       16.29  3.71    Male     No    Sunday  Dinner   3.0
# 18            19       16.97  3.50  Female     No       Sun  Dinner   3.0
# 19            20       20.65  3.35    Male     No  Saturday  Dinner   3.0
# 20            21       17.92  4.08    Male     No       Sat  Dinner   2.0
# 21            22       20.29  2.75  Female     No       Sat  Dinner   2.0
# 22            23       15.77  2.23  Female     No       Sat  Dinner   2.0
# 23            24       39.42  7.58    Male     No       Sat  Dinner   4.0
# 24            25       19.82  3.18    Male     No       Sat  Dinner   2.0
# 25            26       17.81  2.34    Male     No       Sat  Dinner   4.0
# 26            27       13.37  2.00    Male     No       Sat  Dinner   2.0
# 27            28       12.69  2.00    Male     No  saturday  Dinner   2.0
# 28            29       21.70  4.30    Male     No       Sat  Dinner   2.0
# 29            30       19.65  3.00  Female     No       Sat  Dinner   2.0
# ..           ...         ...   ...     ...    ...       ...     ...   ...
# 221          219       28.17  6.50  Female    Yes       Sat  Dinner   3.0
# 222          220       12.90  1.10  Female    Yes       Sat  Dinner   2.0
# 223          221       28.15  3.00    Male    Yes       Sat  Dinner   5.0
# 224          222       11.59  1.50    Male    Yes       Sat  Dinner   2.0
# 225          223        7.74  1.44    Male    Yes       Sat  Dinner   2.0
# 226          224       30.14  3.09  Female    Yes       Sat  Dinner   4.0
# 227          225       12.16  2.20    Male    Yes       Fri   Lunch   2.0
# 228          226       13.42  3.48  Female    Yes       Fri   Lunch   2.0
# 229          227        8.58  1.92    Male    Yes    Friday   Lunch   1.0
# 230          228       15.98  3.00  Female     No    Friday   Lunch   3.0
# 231          229       13.42  1.58    Male    Yes       Fri   Lunch   2.0
# 232          230       16.27  2.50  Female    Yes       Fri   Lunch   2.0
# 233          231       10.09  2.00  Female    Yes       Fri   Lunch   2.0
# 234          232       20.45  3.00    Male     No       Sat  Dinner   4.0
# 235          233       13.28  2.72    Male     No       Sat  Dinner   2.0
# 236          234       22.12  2.88  Female    Yes       Sat  Dinner   2.0
# 237          235       24.01  2.00    Male    Yes       Sat  Dinner   4.0
# 238          236       15.69  3.00    Male    Yes       Sat  Dinner   3.0
# 239          237       11.61  3.39    Male     No       Sat  Dinner   2.0
# 240          238       10.77  1.47    Male     No       Sat  Dinner   2.0
# 241          239       15.53  3.00    Male    Yes       Sat  Dinner   2.0
# 242          240       10.07  1.25    Male     No       Sat  Dinner   2.0
# 243          241       12.60  1.00    Male    Yes       Sat  Dinner   2.0
# 244          242       32.83  1.17    Male    Yes       Sat  Dinner   2.0
# 245          243       35.83  4.67  Female     No       Sat  Dinner   3.0
# 246          244       29.03  5.92    Male     No       Sat  Dinner   3.0
# 247          245       27.18  2.00  Female    Yes       Sat  Dinner   2.0
# 248          246       22.67  2.00    Male    Yes       Sat  Dinner   2.0
# 249          247       17.82  1.75    Male     No       Sat  Dinner   2.0
# 250          248       18.78  3.00  Female     No      Thur  Dinner   2.0
#
# [246 rows x 8 columns]

# %%
tips = tips.drop_duplicates()

# %% [markdown]
# ## Summarizing and Computing Descriptive Statistics

# %%
tips.describe()
# Out:
#        customer_id  total_bill         tip        size
# count   247.000000  247.000000  247.000000  247.000000
# mean    124.882591   19.829555    3.001984    2.574899
# std      71.855026    8.901847    1.383686    0.950747
# min       1.000000    3.070000    1.000000    1.000000
# 25%      62.500000   13.380000    2.000000    2.000000
# 50%     126.000000   17.810000    2.880000    2.000000
# 75%     186.500000   24.175000    3.575000    3.000000
# max     248.000000   50.810000   10.000000    6.000000

# %%
tips.total_bill.mean()
# Out:
# 19.829554655870453

# %%
tips.total_bill.quantile(0.25)
# Out:
# 13.379999999999999

# %%
tips.cumsum()
# Out:
#     customer_id total_bill     tip  \
# 0             1      16.99    1.01
# 1             3      27.33    2.67
# 2             6      48.34    6.17
# 3            10      72.02    9.48
# 4            15      96.61   13.09
# 5            21      121.9    17.8
# 6            28     130.67    19.8
# 7            36     157.55   22.92
# 8            45     172.59   24.88
# 9            55     187.37   28.11
# 10           66     197.64   29.82
# 11           78      232.9   34.82
# 12           91     248.32   36.39
# 13          105     266.75   39.39
# 14          120     281.58   42.41
# 15          136     303.16   46.33
# 16          153     313.49      48
# 17          171     329.78   51.71
# 18          190     346.75   55.21
# 19          210      367.4   58.56
# 20          231     385.32   62.64
# 21          253     405.61   65.39
# 22          276     421.38   67.62
# 23          300      460.8    75.2
# 24          325     480.62   78.38
# 25          351     498.43   80.72
# 26          378      511.8   82.72
# 27          406     524.49   84.72
# 28          435     546.19   89.02
# 29          465     565.84   92.02
# ..          ...        ...     ...
# 221       24060    4377.19  670.46
# 222       24280    4390.09  671.56
# 223       24501    4418.24  674.56
# 224       24723    4429.83  676.06
# 225       24946    4437.57   677.5
# 226       25170    4467.71  680.59
# 227       25395    4479.87  682.79
# 228       25621    4493.29  686.27
# 229       25848    4501.87  688.19
# 230       26076    4517.85  691.19
# 231       26305    4531.27  692.77
# 232       26535    4547.54  695.27
# 233       26766    4557.63  697.27
# 234       26998    4578.08  700.27
# 235       27231    4591.36  702.99
# 236       27465    4613.48  705.87
# 237       27700    4637.49  707.87
# 238       27936    4653.18  710.87
# 239       28173    4664.79  714.26
# 240       28411    4675.56  715.73
# 241       28650    4691.09  718.73
# 242       28890    4701.16  719.98
# 243       29131    4713.76  720.98
# 244       29373    4746.59  722.15
# 245       29616    4782.42  726.82
# 246       29860    4811.45  732.74
# 247       30105    4838.63  734.74
# 248       30351     4861.3  736.74
# 249       30598    4879.12  738.49
# 250       30846     4897.9  741.49
#
#                                                    sex  \
# 0                                               Female
# 1                                           FemaleMale
# 2                                       FemaleMaleMale
# 3                                   FemaleMaleMaleMale
# 4                             FemaleMaleMaleMaleFemale
# 5                         FemaleMaleMaleMaleFemaleMale
# 6                     FemaleMaleMaleMaleFemaleMaleMale
# 7                 FemaleMaleMaleMaleFemaleMaleMaleMale
# 8             FemaleMaleMaleMaleFemaleMaleMaleMaleMale
# 9         FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMale
# 10    FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMale
# 11   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 12   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 13   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 14   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 15   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 16   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 17   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 18   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 19   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 20   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 21   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 22   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 23   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 24   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 25   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 26   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 27   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 28   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 29   FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# ..                                                 ...
# 221  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 222  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 223  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 224  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 225  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 226  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 227  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 228  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 229  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 230  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 231  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 232  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 233  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 234  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 235  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 236  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 237  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 238  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 239  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 240  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 241  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 242  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 243  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 244  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 245  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 246  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 247  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 248  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 249  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 250  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
#
#                                                 smoker  \
# 0                                                   No
# 1                                                 NoNo
# 2                                               NoNoNo
# 3                                             NoNoNoNo
# 4                                           NoNoNoNoNo
# 5                                         NoNoNoNoNoNo
# 6                                       NoNoNoNoNoNoNo
# 7                                     NoNoNoNoNoNoNoNo
# 8                                   NoNoNoNoNoNoNoNoNo
# 9                                 NoNoNoNoNoNoNoNoNoNo
# 10                              NoNoNoNoNoNoNoNoNoNoNo
# 11                            NoNoNoNoNoNoNoNoNoNoNoNo
# 12                          NoNoNoNoNoNoNoNoNoNoNoNoNo
# 13                        NoNoNoNoNoNoNoNoNoNoNoNoNoNo
# 14                      NoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
# 15                    NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
# 16                  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
# 17                NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
# 18              NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
# 19            NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
# 20          NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
# 21        NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
# 22      NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
# 23    NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
# 24   NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 25   NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 26   NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 27   NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 28   NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 29   NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# ..                                                 ...
# 221  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 222  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 223  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 224  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 225  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 226  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 227  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 228  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 229  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 230  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 231  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 232  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 233  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 234  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 235  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 236  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 237  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 238  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 239  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 240  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 241  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 242  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 243  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 244  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 245  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 246  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 247  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 248  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 249  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 250  NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
#
#                                                    day  \
# 0                                                  Sun
# 1                                            SunSunday
# 2                                         SunSundaySun
# 3                                      SunSundaySunSun
# 4                                   SunSundaySunSunSun
# 5                                SunSundaySunSunSunSun
# 6                             SunSundaySunSunSunSunSun
# 7                       SunSundaySunSunSunSunSunSunday
# 8                    SunSundaySunSunSunSunSunSundaySun
# 9                 SunSundaySunSunSunSunSunSundaySunSun
# 10             SunSundaySunSunSunSunSunSundaySunSunSun
# 11       SunSundaySunSunSunSunSunSundaySunSunSunSunday
# 12    SunSundaySunSunSunSunSunSundaySunSunSunSundaySun
# 13   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 14   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 15   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 16   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 17   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 18   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 19   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 20   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 21   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 22   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 23   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 24   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 25   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 26   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 27   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 28   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 29   SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# ..                                                 ...
# 221  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 222  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 223  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 224  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 225  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 226  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 227  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 228  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 229  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 230  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 231  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 232  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 233  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 234  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 235  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 236  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 237  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 238  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 239  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 240  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 241  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 242  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 243  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 244  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 245  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 246  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 247  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 248  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 249  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
# 250  SunSundaySunSunSunSunSunSundaySunSunSunSundayS...
#
#                                                   time size
# 0                                               Dinner    2
# 1                                         DinnerDinner    5
# 2                                   DinnerDinnerDinner    8
# 3                             DinnerDinnerDinnerDinner   10
# 4                       DinnerDinnerDinnerDinnerDinner   14
# 5                 DinnerDinnerDinnerDinnerDinnerDinner   18
# 6           DinnerDinnerDinnerDinnerDinnerDinnerDinner   20
# 7     DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinner   24
# 8    DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   26
# 9    DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   28
# 10   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   30
# 11   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   34
# 12   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   36
# 13   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   40
# 14   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   42
# 15   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   44
# 16   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   47
# 17   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   50
# 18   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   53
# 19   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   56
# 20   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   58
# 21   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   60
# 22   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   62
# 23   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   66
# 24   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   68
# 25   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   72
# 26   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   74
# 27   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   76
# 28   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   78
# 29   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   80
# ..                                                 ...  ...
# 221  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  566
# 222  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  568
# 223  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  573
# 224  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  575
# 225  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  577
# 226  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  581
# 227  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  583
# 228  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  585
# 229  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  586
# 230  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  589
# 231  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  591
# 232  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  593
# 233  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  595
# 234  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  599
# 235  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  601
# 236  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  603
# 237  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  607
# 238  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  610
# 239  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  612
# 240  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  614
# 241  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  616
# 242  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  618
# 243  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  620
# 244  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  622
# 245  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  625
# 246  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  628
# 247  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  630
# 248  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  632
# 249  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  634
# 250  DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...  636
#
# [247 rows x 8 columns]

# %%
tips.tip.idxmax()
# Out:
# 177

# %%
tips.tip.max()
# Out:
# 10.0

# %%
tips.loc[177, :]
# Out:
# customer_id       175
# total_bill      50.81
# tip                10
# sex              Male
# smoker            Yes
# day               Sat
# time           Dinner
# size                3
# Name: 177, dtype: object

# %%
tips.tip / tips.total_bill
# Out:
# 0      0.059447
# 1      0.160542
# 2      0.166587
# 3      0.139780
# 4      0.146808
# 5      0.186240
# 6      0.228050
# 7      0.116071
# 8      0.130319
# 9      0.218539
# 10     0.166504
# 11     0.141804
# 12     0.101816
# 13     0.162778
# 14     0.203641
# 15     0.181650
# 16     0.161665
# 17     0.227747
# 18     0.206246
# 19     0.162228
# 20     0.227679
# 21     0.135535
# 22     0.141408
# 23     0.192288
# 24     0.160444
# 25     0.131387
# 26     0.149589
# 27     0.157604
# 28     0.198157
# 29     0.152672
#          ...
# 221    0.230742
# 222    0.085271
# 223    0.106572
# 224    0.129422
# 225    0.186047
# 226    0.102522
# 227    0.180921
# 228    0.259314
# 229    0.223776
# 230    0.187735
# 231    0.117735
# 232    0.153657
# 233    0.198216
# 234    0.146699
# 235    0.204819
# 236    0.130199
# 237    0.083299
# 238    0.191205
# 239    0.291990
# 240    0.136490
# 241    0.193175
# 242    0.124131
# 243    0.079365
# 244    0.035638
# 245    0.130338
# 246    0.203927
# 247    0.073584
# 248    0.088222
# 249    0.098204
# 250    0.159744
# Length: 247, dtype: float64

# %% [markdown]
# ## Function application and mapping

# %% [markdown]
# #### 숫자 다루기

# %%
tips[['total_bill', 'tip']].apply(lambda x: x.max())
# Out:
# total_bill    50.81
# tip           10.00
# dtype: float64

# %%
tips[['total_bill', 'tip']].apply(lambda x: x.max() - x.min(), axis=1)
# Out:
# 0      15.98
# 1       8.68
# 2      17.51
# 3      20.37
# 4      20.98
# 5      20.58
# 6       6.77
# 7      23.76
# 8      13.08
# 9      11.55
# 10      8.56
# 11     30.26
# 12     13.85
# 13     15.43
# 14     11.81
# 15     17.66
# 16      8.66
# 17     12.58
# 18     13.47
# 19     17.30
# 20     13.84
# 21     17.54
# 22     13.54
# 23     31.84
# 24     16.64
# 25     15.47
# 26     11.37
# 27     10.69
# 28     17.40
# 29     16.65
#        ...
# 221    21.67
# 222    11.80
# 223    25.15
# 224    10.09
# 225     6.30
# 226    27.05
# 227     9.96
# 228     9.94
# 229     6.66
# 230    12.98
# 231    11.84
# 232    13.77
# 233     8.09
# 234    17.45
# 235    10.56
# 236    19.24
# 237    22.01
# 238    12.69
# 239     8.22
# 240     9.30
# 241    12.53
# 242     8.82
# 243    11.60
# 244    31.66
# 245    31.16
# 246    23.11
# 247    25.18
# 248    20.67
# 249    16.07
# 250    15.78
# Length: 247, dtype: float64

# %%
tips['tip'].apply(lambda x: x - 0.5)
# Out:
# 0      0.51
# 1      1.16
# 2      3.00
# 3      2.81
# 4      3.11
# 5      4.21
# 6      1.50
# 7      2.62
# 8      1.46
# 9      2.73
# 10     1.21
# 11     4.50
# 12     1.07
# 13     2.50
# 14     2.52
# 15     3.42
# 16     1.17
# 17     3.21
# 18     3.00
# 19     2.85
# 20     3.58
# 21     2.25
# 22     1.73
# 23     7.08
# 24     2.68
# 25     1.84
# 26     1.50
# 27     1.50
# 28     3.80
# 29     2.50
#        ...
# 221    6.00
# 222    0.60
# 223    2.50
# 224    1.00
# 225    0.94
# 226    2.59
# 227    1.70
# 228    2.98
# 229    1.42
# 230    2.50
# 231    1.08
# 232    2.00
# 233    1.50
# 234    2.50
# 235    2.22
# 236    2.38
# 237    1.50
# 238    2.50
# 239    2.89
# 240    0.97
# 241    2.50
# 242    0.75
# 243    0.50
# 244    0.67
# 245    4.17
# 246    5.42
# 247    1.50
# 248    1.50
# 249    1.25
# 250    2.50
# Name: tip, Length: 247, dtype: float64

# %%
def f(x):
    return x*2
tips['tip'].apply(f)
# Out:
# 0       2.02
# 1       3.32
# 2       7.00
# 3       6.62
# 4       7.22
# 5       9.42
# 6       4.00
# 7       6.24
# 8       3.92
# 9       6.46
# 10      3.42
# 11     10.00
# 12      3.14
# 13      6.00
# 14      6.04
# 15      7.84
# 16      3.34
# 17      7.42
# 18      7.00
# 19      6.70
# 20      8.16
# 21      5.50
# 22      4.46
# 23     15.16
# 24      6.36
# 25      4.68
# 26      4.00
# 27      4.00
# 28      8.60
# 29      6.00
#        ...
# 221    13.00
# 222     2.20
# 223     6.00
# 224     3.00
# 225     2.88
# 226     6.18
# 227     4.40
# 228     6.96
# 229     3.84
# 230     6.00
# 231     3.16
# 232     5.00
# 233     4.00
# 234     6.00
# 235     5.44
# 236     5.76
# 237     4.00
# 238     6.00
# 239     6.78
# 240     2.94
# 241     6.00
# 242     2.50
# 243     2.00
# 244     2.34
# 245     9.34
# 246    11.84
# 247     4.00
# 248     4.00
# 249     3.50
# 250     6.00
# Name: tip, Length: 247, dtype: float64

# %% [markdown]
# #### 문자 다루기

# %%
tips.day.replace('Friday', 'Fri')
# Out:
# 0           Sun
# 1        Sunday
# 2           Sun
# 3           Sun
# 4           Sun
# 5           Sun
# 6           Sun
# 7        Sunday
# 8           Sun
# 9           Sun
# 10          Sun
# 11       Sunday
# 12          Sun
# 13          Sun
# 14       Sunday
# 15          Sun
# 16       Sunday
# 17       Sunday
# 18          Sun
# 19     Saturday
# 20          Sat
# 21          Sat
# 22          Sat
# 23          Sat
# 24          Sat
# 25          Sat
# 26          Sat
# 27     saturday
# 28          Sat
# 29          Sat
#          ...
# 221         Sat
# 222         Sat
# 223         Sat
# 224         Sat
# 225         Sat
# 226         Sat
# 227         Fri
# 228         Fri
# 229         Fri
# 230         Fri
# 231         Fri
# 232         Fri
# 233         Fri
# 234         Sat
# 235         Sat
# 236         Sat
# 237         Sat
# 238         Sat
# 239         Sat
# 240         Sat
# 241         Sat
# 242         Sat
# 243         Sat
# 244         Sat
# 245         Sat
# 246         Sat
# 247         Sat
# 248         Sat
# 249         Sat
# 250        Thur
# Name: day, Length: 247, dtype: object

# %%
tips.day.replace(['Friday', 'fri'], 'Fri')
# Out:
# 0           Sun
# 1        Sunday
# 2           Sun
# 3           Sun
# 4           Sun
# 5           Sun
# 6           Sun
# 7        Sunday
# 8           Sun
# 9           Sun
# 10          Sun
# 11       Sunday
# 12          Sun
# 13          Sun
# 14       Sunday
# 15          Sun
# 16       Sunday
# 17       Sunday
# 18          Sun
# 19     Saturday
# 20          Sat
# 21          Sat
# 22          Sat
# 23          Sat
# 24          Sat
# 25          Sat
# 26          Sat
# 27     saturday
# 28          Sat
# 29          Sat
#          ...
# 221         Sat
# 222         Sat
# 223         Sat
# 224         Sat
# 225         Sat
# 226         Sat
# 227         Fri
# 228         Fri
# 229         Fri
# 230         Fri
# 231         Fri
# 232         Fri
# 233         Fri
# 234         Sat
# 235         Sat
# 236         Sat
# 237         Sat
# 238         Sat
# 239         Sat
# 240         Sat
# 241         Sat
# 242         Sat
# 243         Sat
# 244         Sat
# 245         Sat
# 246         Sat
# 247         Sat
# 248         Sat
# 249         Sat
# 250        Thur
# Name: day, Length: 247, dtype: object

# %%
dict_day = {'Friday': 'Fri'}
tips.day.map(dict_day)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
#       ...
# 221    NaN
# 222    NaN
# 223    NaN
# 224    NaN
# 225    NaN
# 226    NaN
# 227    NaN
# 228    NaN
# 229    Fri
# 230    Fri
# 231    NaN
# 232    NaN
# 233    NaN
# 234    NaN
# 235    NaN
# 236    NaN
# 237    NaN
# 238    NaN
# 239    NaN
# 240    NaN
# 241    NaN
# 242    NaN
# 243    NaN
# 244    NaN
# 245    NaN
# 246    NaN
# 247    NaN
# 248    NaN
# 249    NaN
# 250    NaN
# Name: day, Length: 247, dtype: object

# %%
tips['day'].apply(str.lower) # tips['day'].apply(lambda x: str.lower(x))도 가능
# Out:
# 0           sun
# 1        sunday
# 2           sun
# 3           sun
# 4           sun
# 5           sun
# 6           sun
# 7        sunday
# 8           sun
# 9           sun
# 10          sun
# 11       sunday
# 12          sun
# 13          sun
# 14       sunday
# 15          sun
# 16       sunday
# 17       sunday
# 18          sun
# 19     saturday
# 20          sat
# 21          sat
# 22          sat
# 23          sat
# 24          sat
# 25          sat
# 26          sat
# 27     saturday
# 28          sat
# 29          sat
#          ...
# 221         sat
# 222         sat
# 223         sat
# 224         sat
# 225         sat
# 226         sat
# 227         fri
# 228         fri
# 229      friday
# 230      friday
# 231         fri
# 232         fri
# 233         fri
# 234         sat
# 235         sat
# 236         sat
# 237         sat
# 238         sat
# 239         sat
# 240         sat
# 241         sat
# 242         sat
# 243         sat
# 244         sat
# 245         sat
# 246         sat
# 247         sat
# 248         sat
# 249         sat
# 250        thur
# Name: day, Length: 247, dtype: object

# %% [markdown]
# ### 실습 3) apply 함수를 이용하여 describe 함수를 구현하라. (tips[['total_bill', 'tip']]에만 적용 가능하면 됨)
# 1. count, mean, std, min, 25%, 50%, 75%, max 값을 인덱스로 하는 Series를 return 하는 함수 정의
# 2. apply 함수로 tips[['total_bill', 'tip']]에 1에서 정의한 함수 적용

# %% [markdown]
# ### 실습 4) tips 데이터의 day 값을 4가지 분류로 통일하여라.
# 1. tips 데이터의 day 값 구성 파악
# 2. day 값을 4가지 분류로 나누는 dictionary 정의
# 3. map 또는 replace를 이용하여 day 값을 4가지 분류로 통일

# %%
tips.day = tips.day.replace(day_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-cb437fed2e2f> in <module>()
# ----> 1 tips.day = tips.day.replace(day_dict)
#
# NameError: name 'day_dict' is not defined

# %% [markdown]
# ## Data Aggregation and Group Operations
# - split: 특정 기준으로 데이터를 그룹핑
# - apply: 각 그룹에 특정 함수를 적용
# - combine: 각 그룹에 함수를 적용한 결과를 묶어서 제시
# <br>
# <img src="https://i.stack.imgur.com/sgCn1.jpg" alt="Drawing" style="width: 450px;"/>

# %%
tips.groupby('sex')

# %%
tips.groupby('sex').groups

# %%
grouped_sex = tips.groupby('sex')
grouped_sex.mean()
# tips.groupby('sex').mean()

# %%
tips.groupby(['sex', 'day']).count()['customer_id']

# %% [markdown]
# ### Iterating over groups

# %%
for name, group in tips.groupby('smoker'):
    print (name)
    print (group)

# %%
for (name1, name2), group in tips.groupby(['sex', 'smoker']):
    print (name1, name2)
    print (group)

# %% [markdown]
# ### Apply function

# %%
def f(x):
    return x.head()
tips.groupby(['sex', 'smoker']).apply(f)

# %% [markdown]
# ### 실습 5) 성별과 흡연 여부로 그룹핑 했을 때, 각 그룹에서 tip을 가장 많이 준 순서대로 5개씩의 전체 데이터를 보여라.
# 1. tip을 가장 많이 준 순서대로 5개씩 보여주는 함수 정의
# 2. groupby 함수를 이용해서 1에서 정의한 함수 적용

# %% [markdown]
# ## Data transformation

# %% [markdown]
# ### Stack & Unstack

# %%
tips.groupby(['sex', 'day']).count()['customer_id']

# %%
tips.groupby(['sex', 'day']).count()['customer_id'].unstack()

# %% [markdown]
# ### Pivot table

# %%
tips.pivot_table(values='tip', index='sex', columns='day', aggfunc='mean')

# %%
tips.pivot_table(values='customer_id', index='sex', columns='day', aggfunc='count')

# %% [markdown]
# ### 실습 6) 각 요일별 성별별 지출 대비 팁의 비율(%)의 평균을 구하라.
# 1. 지출 대비 팁의 비율의 평균을 구하는 함수 정의
# 2. groupby 함수를 이용하여 1에서 정의한 함수를 각 그룹에 적용
# 3. stack 또는 unstack을 이용해 dataframe 변형
