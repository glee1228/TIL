# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
matplotlib inline

# %% [markdown]
# # 1. matplotlib

# %% [markdown]
# ## 1.1 Figures and Subplots

# %%
plt.plot(randn(50), 'k--')

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(1, 2,3)
# Out:
# /Users/donghoon/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-b1028fc90be2> in <module>()
#       1 ax1 = fig.add_subplot(2, 2, 1)
#       2 ax2 = fig.add_subplot(2, 2, 2)
# ----> 3 ax3 = fig.add_subplot(1, 2,3)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1237                     self._axstack.remove(ax)
#    1238
# ...

# %%
fig

# %%
ax1.hist(randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))
ax3.plot(np.random.randn(50).cumsum(), 'k--')
fig

# %%
fig, axes = plt.subplots(2, 3)
axes[0, 1].plot(randn(50).cumsum(), 'k--')

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=False)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0.2, hspace=0)

# %% [markdown]
# ## 1.2 Colors, Markers, and Line Styles

# %%
fig, axes = plt.subplots(2, 2)
axes[0,0].plot(randn(50).cumsum(), 'k--')
axes[0,1].plot(randn(50).cumsum(), 'ko--')
axes[1,0].plot(randn(20).cumsum(), linestyle='solid', color='k', marker='+')
axes[1,1].plot(randn(50).cumsum(), linestyle='dotted', color='g')

# %%
data = randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %% [markdown]
# ## 1.3 Ticks, Labels, and Legend

# %%
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum())

ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                            rotation=30, fontsize='small')
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')
ax.set_ylabel('Values')
ax.set_xlim([0, 1100])
# Out:
# (0, 1100)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')
ax.legend(loc='best')

# %% [markdown]
# ## 1.4 Annotations and Drawing on a Subplot

# %%
pd.read_csv('spx.csv')
# Out:
#                Unnamed: 0      SPX
# 0     1990-02-01 00:00:00   328.79
# 1     1990-02-02 00:00:00   330.92
# 2     1990-02-05 00:00:00   331.85
# 3     1990-02-06 00:00:00   329.66
# 4     1990-02-07 00:00:00   333.75
# 5     1990-02-08 00:00:00   332.96
# 6     1990-02-09 00:00:00   333.62
# 7     1990-02-12 00:00:00   330.08
# 8     1990-02-13 00:00:00   331.02
# 9     1990-02-14 00:00:00   332.01
# 10    1990-02-15 00:00:00   334.89
# 11    1990-02-16 00:00:00   332.72
# 12    1990-02-20 00:00:00   327.99
# 13    1990-02-21 00:00:00   327.67
# 14    1990-02-22 00:00:00   325.70
# 15    1990-02-23 00:00:00   324.15
# 16    1990-02-26 00:00:00   328.67
# 17    1990-02-27 00:00:00   330.26
# 18    1990-02-28 00:00:00   331.89
# 19    1990-03-01 00:00:00   332.74
# 20    1990-03-02 00:00:00   335.54
# 21    1990-03-05 00:00:00   333.74
# 22    1990-03-06 00:00:00   337.93
# 23    1990-03-07 00:00:00   336.95
# 24    1990-03-08 00:00:00   340.27
# 25    1990-03-09 00:00:00   337.93
# ...

# %%
pd.read_csv('spx.csv', index_col=0, parse_dates=True)
# Out:
#                 SPX
# 1990-02-01   328.79
# 1990-02-02   330.92
# 1990-02-05   331.85
# 1990-02-06   329.66
# 1990-02-07   333.75
# 1990-02-08   332.96
# 1990-02-09   333.62
# 1990-02-12   330.08
# 1990-02-13   331.02
# 1990-02-14   332.01
# 1990-02-15   334.89
# 1990-02-16   332.72
# 1990-02-20   327.99
# 1990-02-21   327.67
# 1990-02-22   325.70
# 1990-02-23   324.15
# 1990-02-26   328.67
# 1990-02-27   330.26
# 1990-02-28   331.89
# 1990-03-01   332.74
# 1990-03-02   335.54
# 1990-03-05   333.74
# 1990-03-06   337.93
# 1990-03-07   336.95
# 1990-03-08   340.27
# 1990-03-09   337.93
# 1990-03-12   338.67
# 1990-03-13   336.00
# 1990-03-14   336.87
# 1990-03-15   338.07
# ...             ...
# 2011-09-02  1173.97
# 2011-09-06  1165.24
# 2011-09-07  1198.62
# 2011-09-08  1185.90
# 2011-09-09  1154.23
# 2011-09-12  1162.27
# 2011-09-13  1172.87
# 2011-09-14  1188.68
# 2011-09-15  1209.11
# 2011-09-16  1216.01
# 2011-09-19  1204.09
# 2011-09-20  1202.09
# 2011-09-21  1166.76
# ...

# %%
#from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(style='k-')
#spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 50),
                xytext=(date, spx.asof(date) + 300),
                arrowprops=dict(facecolor='red'),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1900])

ax.set_title('Important dates in 2008-2009 financial crisis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-765878bc3717> in <module>()
#      11
#      12 crisis_data = [
# ---> 13     (datetime(2007, 10, 11), 'Peak of bull market'),
#      14     (datetime(2008, 3, 12), 'Bear Stearns Fails'),
#      15     (datetime(2008, 9, 15), 'Lehman Bankruptcy')
#
# NameError: name 'datetime' is not defined

# %%
#from datetime import datetime

#fig = plt.figure()
#ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(style='k-')
#spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 50),
                xytext=(date, spx.asof(date) + 300),
                arrowprops=dict(facecolor='red'),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1900])

ax.set_title('Important dates in 2008-2009 financial crisis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-0d1dfa6933b7> in <module>()
#      11
#      12 crisis_data = [
# ---> 13     (datetime(2007, 10, 11), 'Peak of bull market'),
#      14     (datetime(2008, 3, 12), 'Bear Stearns Fails'),
#      15     (datetime(2008, 9, 15), 'Lehman Bankruptcy')
#
# NameError: name 'datetime' is not defined

# %% [markdown]
# ### patches

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color='g', alpha=0.5)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
fig = plt.figure()
#ax = fig.add_subplot(1, 1, 1)

plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
#plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
#plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color='g', alpha=0.5)

#ax.add_patch(rect)
#ax.add_patch(circ)
#ax.add_patch(pgon)

# %% [markdown]
# ## 1.6 matplotlib Configuration

# %%
font_options = {'family' : 'serif',
               'weight' : 'bold'}
plt.rc('font', **font_options)
plt.rc('figure', figsize=(5, 5))

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(randn(1000).cumsum())
ax.set_xlabel('Stages')
# Out:
# Text(0.5,0,'Stages')

# %% [markdown]
# # 2. Plotting in pandas

# %% [markdown]
# ## 2.1 Line Plots

# %%
from pandas import Series
s = Series(np.random.randn(10).cumsum(), 
           index=np.arange(0, 100, 10))
s.plot()

# %%
from pandas import DataFrame
df = DataFrame(np.random.randn(20, 4).cumsum(0),
               columns=['A', 'B', 'C', 'D'],
               index=np.arange(0, 100, 5))
df.plot()

# %% [markdown]
# ## 2.2 Bar Plots

# %%
fig, axes = plt.subplots(2, 1)
data = Series(np.random.randn(16), index=list('abcdefghijklmnop'))
data.plot(kind='bar', ax=axes[0], color='k', alpha=0.7)
data.plot(kind='barh', ax=axes[1], color='k', alpha=0.7)

# %%
party_counts = pd.DataFrame([[1, 16, 1, 1, 0, 0],
                         [2, 53, 18, 13, 1, 0],
                         [0, 39, 15, 18, 3, 1],
                         [1, 48, 4, 5, 1, 3]],
                        index=['Fri', 'Sat', 'Sun', 'Thur'],
                        columns=[1, 2, 3, 4, 5, 6])

party_counts.index.name = 'day'
party_counts.columns.name = 'size'

# %%
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts.sum(1).astype(float)
# Out:
# day
# Fri     19.0
# Sat     87.0
# Sun     76.0
# Thur    62.0
# dtype: float64

# %%
party_pcts = party_counts.div(party_counts.sum(1).astype(float), axis=0)
party_pcts
# Out:
# size         1         2         3         4         5         6
# day
# Fri   0.052632  0.842105  0.052632  0.052632  0.000000  0.000000
# Sat   0.022989  0.609195  0.206897  0.149425  0.011494  0.000000
# Sun   0.000000  0.513158  0.197368  0.236842  0.039474  0.013158
# Thur  0.016129  0.774194  0.064516  0.080645  0.016129  0.048387

# %%
party_counts.div(party_counts.sum().astype(float), axis=1)
# Out:
# size     1         2         3         4    5     6
# day
# Fri   0.25  0.102564  0.026316  0.027027  0.0  0.00
# Sat   0.50  0.339744  0.473684  0.351351  0.2  0.00
# Sun   0.00  0.250000  0.394737  0.486486  0.6  0.25
# Thur  0.25  0.307692  0.105263  0.135135  0.2  0.75

# %%
party_pcts.plot(kind='bar', stacked=True)

# %% [markdown]
# ## 2.3 Histograms and Density Plots

# %%
df = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000), 
                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])
plt.figure()
df.plot.hist(alpha=0.5)

# %% [markdown]
# ### Stacked Histogram

# %%
plt.figure()
df.plot.hist(stacked=False, bins=20)

# %% [markdown]
# ### Density Plots

# %%
comp1 = np.random.normal(0, 1, size=200)  # N(0, 1)
comp2 = np.random.normal(10, 2, size=200)  # N(10, 4)
values = Series(np.concatenate([comp1, comp2]))
values.hist(bins=100, alpha=0.5, color='k', normed=True)
values.plot(kind='kde', style='r--') # kde: kernel density estimation
# Out:
# /Users/donghoon/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
tips = pd.read_csv('tips.csv')
tips['tip_pct'] = tips['tip'] / tips['total_bill']
tips['tip_pct'].hist(bins=100)
tips['tip_pct'].plot(kind='kde')

# %% [markdown]
# ## 2.4 Scatter Plots

# %%
macro = pd.read_csv('macrodata.csv')
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
trans_data = np.log(data).diff().dropna()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-1a4a062bb07f> in <module>()
# ----> 1 macro = pd.read_csv('macrodata.csv')
#       2 data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
#       3 trans_data = np.log(data).diff().dropna()
#
# ...

# %%
plt.figure()
plt.scatter(trans_data['m1'], trans_data['unemp'])
plt.title('Changes in log %s vs. log %s' % ('m1', 'unemp'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-ae6fbad31aaa> in <module>()
#       1 plt.figure()
# ----> 2 plt.scatter(trans_data['m1'], trans_data['unemp'])
#       3 plt.title('Changes in log %s vs. log %s' % ('m1', 'unemp'))
#
# NameError: name 'trans_data' is not defined
